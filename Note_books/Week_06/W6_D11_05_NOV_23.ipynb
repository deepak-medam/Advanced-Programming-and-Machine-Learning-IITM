# %%
import pandas as pd

# %% [markdown]
# ### Drop Ex:4 Drop duplicate in score_df dataframe.

# %%
names = ['Ram', 'John', 'Abdul','Siva', 'Adam', 'Rahman']
maths =  [45, 40, 60, 80, 90, 75]
english =[60,75,90,65,80,60]
scores = { 'Student_Name':names, 'Maths':maths, 'English':english }
scores_df = pd.DataFrame(scores,index= names)
scores_df
# Out:
#        Student_Name  Maths  English
# Ram             Ram     45       60
# John           John     40       75
# Abdul         Abdul     60       90
# Siva           Siva     80       65
# Adam           Adam     90       80
# Rahman       Rahman     75       60

# %%
scores_df['Class']="Tenth"       # Single values to all the rows
scores_df
# Out:
#        Student_Name  Maths  English  Class
# Ram             Ram     45       60  Tenth
# John           John     40       75  Tenth
# Abdul         Abdul     60       90  Tenth
# Siva           Siva     80       65  Tenth
# Adam           Adam     90       80  Tenth
# Rahman       Rahman     75       60  Tenth

# %%
scores_df['History']=[60,70,80,90,95,97]    # Multiple values to columns
scores_df
# Out:
#        Student_Name  Maths  English  Class  History
# Ram             Ram     45       60  Tenth       60
# John           John     40       75  Tenth       70
# Abdul         Abdul     60       90  Tenth       80
# Siva           Siva     80       65  Tenth       90
# Adam           Adam     90       80  Tenth       95
# Rahman       Rahman     75       60  Tenth       97

# %%
scores_df.loc['kumar']=['Kumar',80,70,'Ninth',60]
scores_df
# Out:
#        Student_Name  Maths  English  Class  History
# Ram             Ram     45       60  Tenth       60
# John           John     40       75  Tenth       70
# Abdul         Abdul     60       90  Tenth       80
# Siva           Siva     80       65  Tenth       90
# Adam           Adam     90       80  Tenth       95
# Rahman       Rahman     75       60  Tenth       97
# kumar         Kumar     80       70  Ninth       60

# %% [markdown]
# ### Dropping rows and columns

# %%
scores_df.drop(['History'],axis=1)        # Dropping single column, axis = 1 is column
# Out:
#        Student_Name  Maths  English  Class
# Ram             Ram     45       60  Tenth
# John           John     40       75  Tenth
# Abdul         Abdul     60       90  Tenth
# Siva           Siva     80       65  Tenth
# Adam           Adam     90       80  Tenth
# Rahman       Rahman     75       60  Tenth
# kumar         Kumar     80       70  Ninth

# %%
scores_df.drop(['History','Class'],axis=1)      # Dropping multiple column
# Out:
#        Student_Name  Maths  English
# Ram             Ram     45       60
# John           John     40       75
# Abdul         Abdul     60       90
# Siva           Siva     80       65
# Adam           Adam     90       80
# Rahman       Rahman     75       60
# kumar         Kumar     80       70

# %%
scores_df
# Out:
#        Student_Name  Maths  English  Class  History
# Ram             Ram     45       60  Tenth       60
# John           John     40       75  Tenth       70
# Abdul         Abdul     60       90  Tenth       80
# Siva           Siva     80       65  Tenth       90
# Adam           Adam     90       80  Tenth       95
# Rahman       Rahman     75       60  Tenth       97
# kumar         Kumar     80       70  Ninth       60

# %%
## drop the column permanent
scores_df.drop(['History'],axis=1,inplace=True)     # Dropping columns permanantly
scores_df
# Out:
#        Student_Name  Maths  English  Class
# Ram             Ram     45       60  Tenth
# John           John     40       75  Tenth
# Abdul         Abdul     60       90  Tenth
# Siva           Siva     80       65  Tenth
# Adam           Adam     90       80  Tenth
# Rahman       Rahman     75       60  Tenth
# kumar         Kumar     80       70  Ninth

# %%
scores_df.drop(['kumar'],axis=0,inplace=True)     # Dropping row wise
scores_df
# Out:
#        Student_Name  Maths  English  Class
# Ram             Ram     45       60  Tenth
# John           John     40       75  Tenth
# Abdul         Abdul     60       90  Tenth
# Siva           Siva     80       65  Tenth
# Adam           Adam     90       80  Tenth
# Rahman       Rahman     75       60  Tenth

# %% [markdown]
# ## IX. Filters

# %%
scores_df
# Out:
#        Student_Name  Maths  English  Class
# Ram             Ram     45       60  Tenth
# John           John     40       75  Tenth
# Abdul         Abdul     60       90  Tenth
# Siva           Siva     80       65  Tenth
# Adam           Adam     90       80  Tenth
# Rahman       Rahman     75       60  Tenth

# %% [markdown]
# ### Filters Ex:1 Fetch the score details where physics score is greater than 70

# %%
x=scores_df[scores_df['English']>70] # Condition based slicing
x
# Out:
#       Student_Name  Maths  English  Class
# John          John     40       75  Tenth
# Abdul        Abdul     60       90  Tenth
# Adam          Adam     90       80  Tenth

# %%
scores_df
# Out:
#        Student_Name  Maths  English  Class
# Ram             Ram     45       60  Tenth
# John           John     40       75  Tenth
# Abdul         Abdul     60       90  Tenth
# Siva           Siva     80       65  Tenth
# Adam           Adam     90       80  Tenth
# Rahman       Rahman     75       60  Tenth

# %% [markdown]
# ### Filters Ex:2 Fetch the score details where Maths score is greater than equal to 75

# %%
scores_df['Maths']
# Out:
# Ram       45
# John      40
# Abdul     60
# Siva      80
# Adam      90
# Rahman    75
# Name: Maths, dtype: int64

# %%
scores_df['Maths']>=75 # output is boolean
# Out:
# Ram       False
# John      False
# Abdul     False
# Siva       True
# Adam       True
# Rahman     True
# Name: Maths, dtype: bool

# %%
scores_df[scores_df['Maths']>=75]
# Out:
#        Student_Name  Maths  English  Class
# Siva           Siva     80       65  Tenth
# Adam           Adam     90       80  Tenth
# Rahman       Rahman     75       60  Tenth

# %% [markdown]
# ### Filters Ex:3 Fetch the score details where Physics score is greater than 70 and Maths score is greater than 60

# %%
scores_df[(scores_df['English']>70)&(scores_df['Maths']>60)] # and condition
# Out:
#      Student_Name  Maths  English  Class
# Adam         Adam     90       80  Tenth

# %%
scores_df[(scores_df['Maths']<65 ) | (scores_df['English']< 60)] # or condition
# Out:
#       Student_Name  Maths  English  Class
# Ram            Ram     45       60  Tenth
# John          John     40       75  Tenth
# Abdul        Abdul     60       90  Tenth

# %% [markdown]
# ## X. Iterating through DataFrame

# %%
scores_df
# Out:
#        Student_Name  Maths  English  Class
# Ram             Ram     45       60  Tenth
# John           John     40       75  Tenth
# Abdul         Abdul     60       90  Tenth
# Siva           Siva     80       65  Tenth
# Adam           Adam     90       80  Tenth
# Rahman       Rahman     75       60  Tenth

# %% [markdown]
# ### Iter Ex: 1

# %%
for index, row in scores_df.iterrows() :
   print(index)
   print(row)
# Out:
# Ram
# Student_Name      Ram
# Maths              45
# English            60
# Class           Tenth
# Name: Ram, dtype: object
# John
# Student_Name     John
# Maths              40
# English            75
# Class           Tenth
# Name: John, dtype: object
# Abdul
# Student_Name    Abdul
# Maths              60
# English            90
# Class           Tenth
# Name: Abdul, dtype: object
# Siva
# Student_Name     Siva
# Maths              80
# English            65
# Class           Tenth
# Name: Siva, dtype: object
# Adam
# Student_Name     Adam
# Maths              90
# English            80
# Class           Tenth
# Name: Adam, dtype: object
# Rahman
# Student_Name    Rahman
# Maths               75
# English             60
# Class            Tenth
# Name: Rahman, dtype: object

# %%
for index,row in scores_df.iterrows():
   print(index+':'+ str(row['English']))
# Out:
# Ram:60
# John:75
# Abdul:90
# Siva:65
# Adam:80
# Rahman:60

# %% [markdown]
# ### We will get error

# %%
for i in scores_df['Physics']:
   print(i)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Physics'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-ddffca6f7297> in <cell line: 1>()
# ----> 1 for i in scores_df['Physics']:
#       2    print(i)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Physics'

# %% [markdown]
# ### Iter Ex: 2

# %%
for row in range(0,scores_df.shape[0]):
   print(scores_df.iloc[row])
# Out:
# Student_Name      Ram
# Maths              45
# English            60
# Class           Tenth
# Name: Ram, dtype: object
# Student_Name     John
# Maths              40
# English            75
# Class           Tenth
# Name: John, dtype: object
# Student_Name    Abdul
# Maths              60
# English            90
# Class           Tenth
# Name: Abdul, dtype: object
# Student_Name     Siva
# Maths              80
# English            65
# Class           Tenth
# Name: Siva, dtype: object
# Student_Name     Adam
# Maths              90
# English            80
# Class           Tenth
# Name: Adam, dtype: object
# Student_Name    Rahman
# Maths               75
# English             60
# Class            Tenth
# Name: Rahman, dtype: object

# %% [markdown]
# ## Series to Dataframe practice

# %%
# create series and convert it into dataframes
s1 = pd.Series([1, 3, 4, 5, 6, 2, 9])           # Define series 1
s2 = pd.Series([1.1, 3.5, 4.7, 5.8, 2.9, 9.3]) # Define series 2
s3 = pd.Series(['a', 'b', 'c', 'd', 'e'])     # Define series 3

Data ={'first':s1, 'second':s2, 'third':s3} # Define Data
dfseries = pd.DataFrame(Data)              # Create DataFrame
dfseries
# Out:
#    first  second third
# 0      1     1.1     a
# 1      3     3.5     b
# 2      4     4.7     c
# 3      5     5.8     d
# 4      6     2.9     e
# 5      2     9.3   NaN
# 6      9     NaN   NaN

# %%
d1 =[[2, 3, 4], [5, 6, 7]] # Define 2d array 1
d2 =[[2, 4, 8], [1, 3, 9]] # Define 2d array 2
Data ={'first': d1, 'second': d2} # Define Data
df2d = pd.DataFrame(Data)    # Create DataFrame
df2d
# Out:
#        first     second
# 0  [2, 3, 4]  [2, 4, 8]
# 1  [5, 6, 7]  [1, 3, 9]

# %% [markdown]
# ## XI. Basic Operations

# %%
data = pd.read_csv('/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Note_books/Week_06/Day_11_Data/Input.csv')
data
# Out:
#     Empid     Name      Dept Gender     City  Salary
# 0       1   Samuel     Admin      M  Chennai   45000
# 1       2    Jerry        IT      M    Blore   75000
# 2       3  Michale     Sales      F      Goa   30000
# 3       4    Joann        IT      F  Chennai   80000
# 4       5   Sherin        IT      F    Blore   78000
# 5       6  Maxwell  Networks      M  Chennai   35000
# 6       7     John     Sales      M  Chennai   28000
# 7       8     Cruz        IT      M  Chennai   89000
# 8       9     Mary        IT      F    Blore   65000
# 9      10    Merry     Sales      F    Blore   45000
# 10     11    Jacob        IT      M      Goa   67000
# 11     12      Liz        IT      F  Kolkata   65000
# 12     13  Saneeta  Networks      F  Kolkata   55000
# 13     14    Jason     Sales      M      Goa   40000
# 14     15     Mike        IT      M  Kolkata    8000

# %%
data['Salary'].min()
# Out:
# 8000

# %%
data['Salary'].max()
# Out:
# 89000

# %%
data['Salary'].mean()
# Out:
# 53666.666666666664

# %%
data['Salary'].std()
# Out:
# 23014.488190413154

# %% [markdown]
# ## XII. Group By

# %% [markdown]
# ### Ex:1 Group by department

# %%
data.groupby('Dept')

# %%
data.groupby('Dept').groups
# Out:
# {'Admin': [0], 'IT': [1, 3, 4, 7, 8, 10, 11, 14], 'Networks': [5, 12], 'Sales': [2, 6, 9, 13]}

# %% [markdown]
# ### Ex:2 Group by first entry in each department

# %%
grp =  data.groupby('Dept')
grp.first()
# Out:
#           Empid     Name Gender     City  Salary
# Dept
# Admin         1   Samuel      M  Chennai   45000
# IT            2    Jerry      M    Blore   75000
# Networks      6  Maxwell      M  Chennai   35000
# Sales         3  Michale      F      Goa   30000

# %% [markdown]
# ### Ex:3 Group by last entry in each department

# %%
grp =  data.groupby('Dept')
grp.last()
# Out:
#           Empid     Name Gender     City  Salary
# Dept
# Admin         1   Samuel      M  Chennai   45000
# IT           15     Mike      M  Kolkata    8000
# Networks     13  Saneeta      F  Kolkata   55000
# Sales        14    Jason      M      Goa   40000

# %% [markdown]
# ### Ex:4 Group by Department and city

# %%
data[['Dept','City']]
# Out:
#         Dept     City
# 0      Admin  Chennai
# 1         IT    Blore
# 2      Sales      Goa
# 3         IT  Chennai
# 4         IT    Blore
# 5   Networks  Chennai
# 6      Sales  Chennai
# 7         IT  Chennai
# 8         IT    Blore
# 9      Sales    Blore
# 10        IT      Goa
# 11        IT  Kolkata
# 12  Networks  Kolkata
# 13     Sales      Goa
# 14        IT  Kolkata

# %%
# print the first entry in each group

grp =  data.groupby(['Dept','City'])
grp.first()
# Out:
#                   Empid     Name Gender  Salary
# Dept     City
# Admin    Chennai      1   Samuel      M   45000
# IT       Blore        2    Jerry      M   75000
#          Chennai      4    Joann      F   80000
#          Goa         11    Jacob      M   67000
#          Kolkata     12      Liz      F   65000
# Networks Chennai      6  Maxwell      M   35000
#          Kolkata     13  Saneeta      F   55000
# Sales    Blore       10    Merry      F   45000
#          Chennai      7     John      M   28000
#          Goa          3  Michale      F   30000

# %%
grp.groups
# Out:
# {('Admin', 'Chennai'): [0], ('IT', 'Blore'): [1, 4, 8], ('IT', 'Chennai'): [3, 7], ('IT', 'Goa'): [10], ('IT', 'Kolkata'): [11, 14], ('Networks', 'Chennai'): [5], ('Networks', 'Kolkata'): [12], ('Sales', 'Blore'): [9], ('Sales', 'Chennai'): [6], ('Sales', 'Goa'): [2, 13]}

# %% [markdown]
# ### Ex:5 Iteration in Group by

# %%
# Group the data based on dept
grp = data.groupby('Dept')

# Iterate data record by record using For loop
for i in grp:
   print(i)
# Out:
# ('Admin',    Empid    Name   Dept Gender     City  Salary
# 0      1  Samuel  Admin      M  Chennai   45000)
# ('IT',     Empid    Name Dept Gender     City  Salary
# 1       2   Jerry   IT      M    Blore   75000
# 3       4   Joann   IT      F  Chennai   80000
# 4       5  Sherin   IT      F    Blore   78000
# 7       8    Cruz   IT      M  Chennai   89000
# 8       9    Mary   IT      F    Blore   65000
# 10     11   Jacob   IT      M      Goa   67000
# 11     12     Liz   IT      F  Kolkata   65000
# 14     15    Mike   IT      M  Kolkata    8000)
# ('Networks',     Empid     Name      Dept Gender     City  Salary
# 5       6  Maxwell  Networks      M  Chennai   35000
# 12     13  Saneeta  Networks      F  Kolkata   55000)
# ('Sales',     Empid     Name   Dept Gender     City  Salary
# 2       3  Michale  Sales      F      Goa   30000
# 6       7     John  Sales      M  Chennai   28000
# 9      10    Merry  Sales      F    Blore   45000
# 13     14    Jason  Sales      M      Goa   40000)

# %%
# Group the data based on dept
grp = data.groupby('Dept')

# Iterate data based on the dept
for dept,group in grp:
   print(dept,group)
# Out:
# Admin    Empid    Name   Dept Gender     City  Salary
# 0      1  Samuel  Admin      M  Chennai   45000
# IT     Empid    Name Dept Gender     City  Salary
# 1       2   Jerry   IT      M    Blore   75000
# 3       4   Joann   IT      F  Chennai   80000
# 4       5  Sherin   IT      F    Blore   78000
# 7       8    Cruz   IT      M  Chennai   89000
# 8       9    Mary   IT      F    Blore   65000
# 10     11   Jacob   IT      M      Goa   67000
# 11     12     Liz   IT      F  Kolkata   65000
# 14     15    Mike   IT      M  Kolkata    8000
# Networks     Empid     Name      Dept Gender     City  Salary
# 5       6  Maxwell  Networks      M  Chennai   35000
# 12     13  Saneeta  Networks      F  Kolkata   55000
# Sales     Empid     Name   Dept Gender     City  Salary
# 2       3  Michale  Sales      F      Goa   30000
# 6       7     John  Sales      M  Chennai   28000
# 9      10    Merry  Sales      F    Blore   45000
# 13     14    Jason  Sales      M      Goa   40000

# %% [markdown]
# ### Ex:6 Get details about one specific group alone

# %%
grp.get_group('IT')
# Out:
#     Empid    Name Dept Gender     City  Salary
# 1       2   Jerry   IT      M    Blore   75000
# 3       4   Joann   IT      F  Chennai   80000
# 4       5  Sherin   IT      F    Blore   78000
# 7       8    Cruz   IT      M  Chennai   89000
# 8       9    Mary   IT      F    Blore   65000
# 10     11   Jacob   IT      M      Goa   67000
# 11     12     Liz   IT      F  Kolkata   65000
# 14     15    Mike   IT      M  Kolkata    8000

# %% [markdown]
# ### Ex:7 Get the count of each group

# %%
grp.size()
# Out:
# Dept
# Admin       1
# IT          8
# Networks    2
# Sales       4
# dtype: int64

# %% [markdown]
# ## XIV. map()
#
# **Series.map(arg, na_action=None)**
#
# Map values of Series according to input correspondence.
#
# Used for substituting each value in a Series with another value, that may be derived from a function, a dict or a

# %%
df = pd.read_csv("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Note_books/Week_06/Day_10_Data/Humidity1.csv")
df
# Out:
#          date      city  temperature  humidity
# 0  05-01-2017  new york           65        56
# 1  05-01-2017  new york           61        54
# 2  05-02-2017  new york           70        60
# 3  05-02-2017  new york           71        62
# 4  05-01-2017    mumbai           75        80
# 5  05-01-2017    mumbai           78        83
# 6  05-02-2017    mumbai           82        85
# 7  05-02-2017    mumbai           80        26

# %%
Season = {'new york':'winter', 'mumbai':'summer'}

# %% [markdown]
# ### Now lets map the above dataframe "season" in our previous dataframe.

# %%
df['Season']=df['city'].map(Season)
df
# Out:
#          date      city  temperature  humidity  Season
# 0  05-01-2017  new york           65        56  winter
# 1  05-01-2017  new york           61        54  winter
# 2  05-02-2017  new york           70        60  winter
# 3  05-02-2017  new york           71        62  winter
# 4  05-01-2017    mumbai           75        80  summer
# 5  05-01-2017    mumbai           78        83  summer
# 6  05-02-2017    mumbai           82        85  summer
# 7  05-02-2017    mumbai           80        26  summer

# %% [markdown]
# ## XV. replace()
#
# **Replace** is used to replace any value in the dataframe. Lets replace the city new york with some other city

# %%
df['city'].replace('new york','Italy')
# Out:
# 0     Italy
# 1     Italy
# 2     Italy
# 3     Italy
# 4    mumbai
# 5    mumbai
# 6    mumbai
# 7    mumbai
# Name: city, dtype: object

# %% [markdown]
# ## XVI. rename()
#
# **Lets rename the column 'temperature' with 'temp'**

# %%
df.rename(columns= {'temperature':'temp'})
# Out:
#          date      city  temp  humidity  Season
# 0  05-01-2017  new york    65        56  winter
# 1  05-01-2017  new york    61        54  winter
# 2  05-02-2017  new york    70        60  winter
# 3  05-02-2017  new york    71        62  winter
# 4  05-01-2017    mumbai    75        80  summer
# 5  05-01-2017    mumbai    78        83  summer
# 6  05-02-2017    mumbai    82        85  summer
# 7  05-02-2017    mumbai    80        26  summer

# %% [markdown]
# #  Visualization: Seaborn and matplotlib
#
# **Package/Libraries** - Matplotlib
#
# **Matplotlib for Python Data Visualization:-**
#
# Matplotlib is oldest and most widely used python visualization package, its a decade old package and it is the most extensively used package for visualizing. Many libraries are built on top of it, and uses its functions in the backend. Its style is very simple and thats the reason plotting is fast in this. It is used to create axis and design the layout for plotting using other libraries like seaborn.
#
# ---
#
# **Package/Libraries** - Seaborn
#
# **Seaborn for Python Data Visualization:-**
#
# Seaborn Python is a data visualization library based on Matplotlib. It provides a high-level interface for drawing attractive statistical graphics. Because seaborn python is built on top of Matplotlib, the graphics can be further tweaked using Matplotlib tools and rendered with any of the Matplotlib backends to generate publication-quality figures

# %% [markdown]
# ### Calling libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings

# %%
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
x = np.linspace(0, 6, 11)
y = x ** 2

# %%
print(x)
print(y)
# Out:
# [0.  0.6 1.2 1.8 2.4 3.  3.6 4.2 4.8 5.4 6. ]
# [ 0.    0.36  1.44  3.24  5.76  9.   12.96 17.64 23.04 29.16 36.  ]

# %% [markdown]
# ### **Line Plot**
#
# **what is the purpose of line plot and where it can be used.**
#
# A line graph is commonly used to display change over time as a series of data points connected by straight line segments on two axes. The line graph therefore helps to determine the relationship between two sets of values, with one data set always being dependent on the other set.

# %%
plt.plot(x, y)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %% [markdown]
# we can observe from above graph/plot for every increase in 'x' there is an increase in 'y',because 'y' is an square of 'x'

# %% [markdown]
# ### Scatter Plot

# %%
plt.scatter(x,y)

# %% [markdown]
# As per our Above plot we interpret that as increase in 'x' there is an increase in 'y',Hence 'y' is an square of 'x'

# %% [markdown]
# ### **Now Let us plot various visualisation plots using seaborn and Matplot libraries For the Given below dataset.**

# %% [markdown]
# ## House Prices Analysis

# %% [markdown]
# ### Reading in data

# %%
df_train = pd.read_csv('/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Note_books/Week_06/Day_11_Data/house_train.csv')

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
df_train.head(3)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
#
# [3 rows x 81 columns]

# %%
df_train.tail(3)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [3 rows x 81 columns]

# %% [markdown]
# ### Looking at the number of rows and columns using shape function

# %%
df_train.shape  # this retrive number of rows,columns
# Out:
# (1460, 81)

# %%
df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %% [markdown]
# ###Bar Plot
#
# **When to use:** If you have comparative data that you would like to represent through a chart then a bar chart would be the best option. This type of chart is one of the more familiar options as it is easy to interpret. These charts are useful for displaying data that is classified into nominal or odinal categories.

# %%
# visualize counts

df_train.SaleCondition.value_counts().plot(kind='bar')
plt.title('House Sale As per There Condition')
plt.ylabel('Counts')
plt.xlabel('Conditions of houses ')
# Out:
# Text(0.5, 0, 'Conditions of houses ')

# %%
df_train.SaleCondition.value_counts()
# Out:
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: SaleCondition, dtype: int64

# %% [markdown]
# ### Pie Plot
#
# **when to use pie plot** :- A pie chart is best used when trying to work out the composition of something. If you have categorical data then using a pie chart would work really well as each slice can represent a different category

# %%
df_train['BldgType'].value_counts().plot(kind='pie')
plt.title('Type of Building')
# Out:
# Text(0.5, 1.0, 'Type of Building')

# %% [markdown]
# we can observe or intrepret from the above pie plot that many buildings constructions where carried out for an 1 family oriented type.
#
# ### Histogram plot
# **When to use :**- A histogram is a great tool for quickly assessing a probability distribution that is intuitively understood by almost any audience. Python offers a handful of different options for building and plotting histograms. Most people know a histogram by its graphical representation, which is similar to a bar graph:
#
# **Y-axis - Counts**
#
# **X-axis - Continous Variable**

# %%
plt.hist(df_train.SalePrice,bins=10,color='r')
plt.show()

# %% [markdown]
# From the above Plot or graph we intrepret that most of the customer who has purchased houses for the sales price mostly ranging between 11-12.

# %% [markdown]
# ### Box plot
# **what is an boxplot:**
#
# --- A Box Plot is the visual representation of the statistical five number summary of a given data set.
#
# Box and whisker plots have been used steadily since their introduction in 1969 and are varied in both their potential visualizations as well as use cases across many disciplines in statistics and data analysis.
#
# **A Five Number Summary includes:-**
#
# **Minimum** - Lowest value/record in that attribute/column.
#
# **First Quartile** -25TH Percentile
#
# **Median (Second Quartile)** - Middle value/record in that attribute/column.
#
# **Third Quartile** - 75TH Percentile
#
# **Maximum** - Lowest value/record in that attribute/column.
#
# **For example** in the number set where x = 1, 2, 3, 5, 6, 9, 10, 11, 12, 13
#
# The **Five Number Summary** would be this:
#
# 13 - **MAX**
#
# 10.75 - **Q3**
#
# 7.5 - **MEDIAN**
#
# 3.5 - **Q1**
#
# 1 - **MIN**

# %%
plt.boxplot(df_train.SalePrice,vert=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x798d87ab0b50>,
#   <matplotlib.lines.Line2D at 0x798d87ab0df0>],
#  'caps': [<matplotlib.lines.Line2D at 0x798d87ab1090>,
#   <matplotlib.lines.Line2D at 0x798d87ab1330>],
#  'boxes': [<matplotlib.lines.Line2D at 0x798d87ab08b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x798d87ab15d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x798d87ab1870>],
#  'means': []}

# %%
df_train.boxplot('SalePrice','SaleCondition');   #shows the distribution of values in the respective attribute

# %% [markdown]
# we can observe from above plot that in normal,abnormal condition houses we have few records/sale price are high priced than normal for that respective salecondition
#
# ### **scatter plot.**
#
# **What is scatter plot** :- A scatter plot is a two-dimensional data visualization that uses dots to represent the values obtained for two different variables - one plotted along the x-axis and the other plotted along the y-axis.
#
# **Where to use scatter plot** :-Scatter plots are used when you want to show the relationship between two variables. Scatter plots are sometimes called correlation plots because they show how two variables are correlated

# %%
df_train.plot.scatter(x='YrSold', y='SalePrice', color='r', title='scatter plot : Year of sold vs Salesprice');

# %% [markdown]
# From the above plot we can intrepret that the sales price for the houses doesn't much vary from year to year except for few houses which are high priced else low priced than normal prices.
#
# ### **Density Plot**
#
# **What is the purpose of density plot/ kde-kernal density plot and where to be used** :-A Density Plot visualises the distribution of data over a continuous interval or time period. This chart is a variation of a Histogram that uses kernel smoothing to plot values, allowing for smoother distributions by smoothing out the noise. The peaks of a Density Plot help display where values are concentrated over the interval.
#
# **An advantage Density Plots have over Histograms**:- is that they're better at determining the distribution shape because they're not affected by the number of bins used (each bar used in a typical histogram). A Histogram comprising of only 4 bins wouldn't produce a distinguishable enough shape of distribution as a 20-bin Histogram would. However, with Density Plots, this isn't an issue.

# %%
df_train.SalePrice.plot(kind='kde', title='Density plot for salesprice', color='gold');

# %% [markdown]
# As seen early in histogram we can configure the same from kde plot that mostly saled price of houses is around 11.8 to 11.9
#
# ### **Area plot**
# **what is the purpose of Area plot** :-An area chart is a good way to demonstrate trends over time to the viewer,This chart is based on the line chart. The filled area can give a greater sense of the trends in a particular dataset.

# %%
df_train['YearBuilt'].value_counts().sort_index().plot.area()   #shows the area of no.of houses built in that respective year.
# Out:
# <Axes: >

# %% [markdown]
# ### Lets plot the same Boxplot with a default seaborn style

# %%
sns.boxplot(data=df_train.SalePrice,color='gold')
plt.show()

# %% [markdown]
# As early we have seen the boxplot using mathplot library its similar to that but colorful.

# %% [markdown]
# ## **Correlation - Heatmap**
#
# **What is an Heatmap:** A heatmap is a two-dimensional graphical representation of data where the individual values that are contained in a matrix are represented as colors. The seaborn python package allows the creation of annotated heatmaps which can be tweaked using Matplotlib tools as per the creator's requirement.
#
#
# **What/How do we interpret from the heat map:** Each square shows the correlation between the variables on each axis. Correlation ranges from -1 to +1. Values closer to zero means there is no linear trend between the two variables. The close to 1 the correlation is the more positively correlated they are; that is as one increases so does the other and the closer to 1 the stronger this relationship is. A correlation closer to -1 is similar, but instead of both increasing one variable will decrease as the other increases.
#
#
# **Correlation:**- Correlation is a statistical measure which tells us about the both strength/magnitude and the direction between 2 variables. A positive correlation indicates the extent to which those variables increase or decrease in parallel; a negative correlation indicates the extent to which one variable increases as the other decreases.
#
# **For Example:- Positive Correlation:-**
# * The more time you spend running on a treadmill, the more calories you will burn.
# * When an employee works more hours his paycheck increases proportionately.
# * The more it rains, the more sales for umbrellas go up.
#
# **Negative Correlation:**
# * If a car decreases speed, travel time to a destination increases.
#
# **No Correlation:-**
#
# * No correlation means that the two variables are not linked, not related, not connected in any way. Neither positive nor
# negative. **example:**-eating cheetos does not make you better at speaking Tamil. They are not related, there is no correlation.

# %%
corrmat = df_train.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %% [markdown]
# we intrepret from the above plot/map that Darker the color means higher negative correlation and lighter the color(white) means high positive correlation. The plot is also symmetrical about the diagonal since the same two variables are being paired together in those squares.
# we can observe that how much do the individual attribute/column correlate to the **sales price**.positve,negative,no correlation with my dependent/saleprice variable.
#
# **Highest positive co-relation of salesprice with -Overall Qual,GrlivArea,Garage car.**
#
# **Highest negative co-relation of salesprice with -KitchenAbvGr,Enclosed porch.**
#
# **No Co-relation with salesprice with GarageYrBuilt.**

# %% [markdown]
# ### **Distplot (Distribution plot).**
#
# **what is an distplot.**
#
# The most convenient way to take a quick look at a distribution in seaborn is the distplot() function. By default, this will draw a histogram and fit a kernel density estimate (KDE).

# %%
sns.distplot(df_train['SalePrice'],bins=10,kde=True);   #this is an histogram representation of distribution of values and bin size sets the size of individual bin.

# %% [markdown]
# We can intrepret from the above plot that in the saleprice distribution where the mostly purchased house was around 15 lakhs.
#
# **Rugplot/distplot:** -Histograms are likely familiar, and a hist function already exists in matplotlib. A histogram represents the distribution of data by forming bins along the range of the data and then drawing bars to show the number of observations that fall in each bin.let’s remove the density curve and add a rug plot, which draws a small vertical tick at each observation. You can make the rug plot itself with the rugplot() function, but it is also available in distplot()

# %%
sns.distplot(df_train['SalePrice'],bins=50,kde=False,rug=True);

# %% [markdown]
# From the above plot we can interpret that the houses where purchased by the customers w priced ranging between 1lakh to 3 lakh

# %% [markdown]
# ### **Pair plot**

# %% [markdown]
# To plot multiple pairwise distributions in a dataset, you can use the pairplot() function. This creates a matrix of axes and shows the relationship for each pair of columns in a DataFrame. by default, it also draws the distribution of each variable on the diagonal Axes:

# %%
sns.set()
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(df_train[cols], size = 2.5)
plt.show();

# %% [markdown]
# ## Additional plot that can used for visulization

# %% [markdown]
# ### **Regression Plot**
#
# **Two main functions in seaborn are used to visualize a linear relationship as determined through regression.**
#
# These functions, regplot() and lmplot() are closely related, and share much of their core functionality. It is important to understand the ways they differ, however, so that you can quickly choose the correct tool for particular job. In the simplest invocation, both functions draw a scatterplot of two variables, x and y, and then fit the regression model y ~ x and plot the resulting regression line and a 95% confidence interval for that regression:

# %%
sns.regplot(data=df_train,
           y="SalePrice",
           x="YearBuilt",
           marker='*',
          color='r')

# Display the plot
plt.show()

# %%
sns.lmplot(data=df_train,
           x="YearBuilt",
           y="SalePrice")

# Display the plot
plt.show()

# %% [markdown]
# **regplot() performs a simple linear regression model fit and plot. lmplot() combines regplot() and FacetGrid.**
#
# **The FacetGrid class helps in visualizing the distribution of one variable as well as the relationship between multiple variables separately within subsets of your dataset using multiple panels.**
#
# **lmplot() is more computationally intensive and is intended as a convenient interface to fit regression models across conditional subsets of a dataset.**

# %% [markdown]
# ### **Strip Plot**
# **what is an strip plot and where it can be used.**
#
# Drawing/plotting a scatterplot where one variable is categorical. A strip plot can be drawn on its own, but it is also a good complement to a box plot in cases where you want to show all observations along with some representation of the underlying distribution.

# %%
sns.stripplot(data=df_train,
             x='SaleCondition',
             y='YearBuilt',
             jitter=True)

plt.show()

# %% [markdown]
# ### **Swarm plot**
# **What is swarm plot and where it can be used.**
#
# Swarm plot used for Drawing/plotting a categorical scatterplot with non-overlapping points. This function is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don’t overlap. This gives a better representation of the distribution of values, but it does not scale well to large numbers of observations. This style of plot is sometimes called a “beeswarm”.

# %%
sns.swarmplot(x='SaleCondition',y='SalePrice',data=df_train)
plt.show()

# %% [markdown]
# ### **Point Plot**
# **what is the purpose of point plot and where to be used.**
#
# A point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars.
#
# Point plots can be more useful than bar plots for focusing comparisons between different levels of one or more categorical variables. They are particularly adept at showing interactions: how the relationship between levels of one categorical variable changes across levels of a second categorical variable.

# %%
sns.pointplot(x="Fireplaces",y="SalePrice",data=df_train,hue="FireplaceQu")

plt.show()
plt.clf()

# %% [markdown]
# ###**Joint Plot.**
# The most familiar way to visualize a distribution is a scatterplot, where each observation is shown with point at the x and y values. This is analgous to a rug plot on two dimensions. You can draw a scatterplot with the matplotlib plt.scatter function, and it is also the default kind of plot shown by the jointplot() function:

# %%
sns.jointplot(df_train['LotFrontage'],df_train['LotArea'],color='gold');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-f4264fbf1522> in <cell line: 1>()
# ----> 1 sns.jointplot(df_train['LotFrontage'],df_train['LotArea'],color='gold');
#
# TypeError: jointplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %% [markdown]
# we can intrepret from above plot that as the increase in Lotfrontage there is an increase in Lotarea.

# %%
plt.scatter(df_train["MasVnrArea"],df_train["SalePrice"])
plt.title("MasVnrArea Vs SalePrice ")
plt.ylabel("SalePrice")
plt.xlabel("Mas Vnr Area in sq feet");

# %% [markdown]
# we can interpret from the above plot that all the time as the increase in Masonry veneer area in square feet there is no mandatory that where will be an increase in salesprice

# %% [markdown]
# ###**Basement variable**

# %%
plt.scatter(df_train["TotalBsmtSF"],df_train["SalePrice"])
plt.title("TotalBsmtSF Vs SalePrice ")
plt.ylabel("SalePrice")
plt.xlabel("TotalBsmtSF");

# %% [markdown]
# we can interpret from the above plot that the increase in Total Basement Square feet has no impact on the Sale price once we cross a particular threshold

# %% [markdown]
# ###**Factorplot**

# %% [markdown]
# **what is the purpose of factor plot and where to be used.**
#
# A Factor plot is similar to point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars.
#
# Factor plots can be more useful than bar plots for focusing comparisons between different levels of one or more categorical variables. They are particularly adept at showing interactions: how the relationship between levels of one categorical variable changes across levels of a second categorical variable.

# %%
sns.factorplot("Fireplaces","SalePrice",data=df_train,hue="FireplaceQu");
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-d793c5e2d267> in <cell line: 1>()
# ----> 1 sns.factorplot("Fireplaces","SalePrice",data=df_train,hue="FireplaceQu");
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'

# %% [markdown]
# In the above example, prices increase with quality and number of fireplaces

# %% [markdown]
# ### **Does amount of 1st floor area help in sales price prediction ?**

# %%
plt.scatter(df_train["1stFlrSF"],df_train.SalePrice, color='red')
plt.title("Sale Price wrt 1st floor")
plt.ylabel('Sale Price (in dollars)')
plt.xlabel("1st Floor in square feet");

# %% [markdown]
# As per our question above ,yes as increase in the first floor area there is an increase in saleprice

# %% [markdown]
# ###**Create a new variables - sales price per sq ft**

# %%
df_train['SalePriceSF'] = df_train['SalePrice']/df_train['GrLivArea']
plt.hist(df_train['SalePriceSF'], bins=15,color="gold")
plt.title("Sale Price per Square Foot")
plt.ylabel('Number of Sales')
plt.xlabel('Price per square feet');
