# %%
import IPython.display as display
from PIL import Image
import pandas as pd

# %% [markdown]
# ## VIII. loc & iloc

# %% [markdown]
# Indexing a DataFrame using iloc[]:
#
# ** .iloc [1:m, 1:n] – **  is used to select or index rows based on their position from 1 to m rows and 1 to n columns
# Indexing a DataFrame using .loc[ ] :
#
# This function selects data by the label of the rows and columns. The df.loc indexer selects data in a different way than just the indexing operator. It can select subsets of rows or columns. It can also simultaneously select subsets of rows and columns.

# %%
image_01 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_06/10.1.png")
display.display(image_01)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=858x635>

# %% [markdown]
# ### Ind Ex:1 Name based row slicing

# %%
names = ['Ram', 'John', 'Abdul','Siva', 'Adam', 'Rahman']
physics =  [45, 40, 60, 80, 90, 75]
maths =[60,75,90,65,80,60]
scores = { 'Names':names, 'Physics':physics, 'Maths':maths } # converted dict
scores_df = pd.DataFrame(scores,index= names)  #DataFrame
print(scores_df)
# Out:
#          Names  Physics  Maths
# Ram        Ram       45     60
# John      John       40     75
# Abdul    Abdul       60     90
# Siva      Siva       80     65
# Adam      Adam       90     80
# Rahman  Rahman       75     60

# %%
scores_df
# Out:
#          Names  Physics  Maths
# Ram        Ram       45     60
# John      John       40     75
# Abdul    Abdul       60     90
# Siva      Siva       80     65
# Adam      Adam       90     80
# Rahman  Rahman       75     60

# %%
scores_df.loc[['Ram']]
# Out:
#     Names  Physics  Maths
# Ram   Ram       45     60

# %% [markdown]
# ### Ind Ex:2 Name based row slicing (multiple rows)

# %%
scores_df.loc[['Ram','Abdul']]
# Out:
#        Names  Physics  Maths
# Ram      Ram       45     60
# Abdul  Abdul       60     90

# %% [markdown]
# ### Ind Ex:3 Slicing based on column

# %%
scores_df.loc[:,['Physics']]
# Out:
#         Physics
# Ram          45
# John         40
# Abdul        60
# Siva         80
# Adam         90
# Rahman       75

# %% [markdown]
# ### Ind Ex:4 Name based row slicing , with specific column

# %%
scores_df.loc[['Ram'],['Physics']]
# Out:
#      Physics
# Ram       45

# %% [markdown]
# ### Ind Ex:5 Name based row slicing , multiple rows with specific column

# %%
scores_df
# Out:
#          Names  Physics  Maths
# Ram        Ram       45     60
# John      John       40     75
# Abdul    Abdul       60     90
# Siva      Siva       80     65
# Adam      Adam       90     80
# Rahman  Rahman       75     60

# %%
scores_df.loc[['Ram','Abdul'],['Physics']]
# Out:
#        Physics
# Ram         45
# Abdul       60

# %% [markdown]
# ### Ind Ex:6 Name based row slicing , multiple rows with multiple columns

# %%
scores_df.loc[['Ram','Abdul'],['Physics','Names']]
# Out:
#        Physics  Names
# Ram         45    Ram
# Abdul       60  Abdul

# %%
scores_df.loc['Ram':'Abdul','Physics':'Maths']
# Out:
#        Physics  Maths
# Ram         45     60
# John        40     75
# Abdul       60     90

# %% [markdown]
# ### Ind Ex:7 Slicing, fetch only the second and third row

# %%
scores_df
# Out:
#          Names  Physics  Maths
# Ram        Ram       45     60
# John      John       40     75
# Abdul    Abdul       60     90
# Siva      Siva       80     65
# Adam      Adam       90     80
# Rahman  Rahman       75     60

# %%
scores_df.iloc[[1,2]]      # iloc - index value
# Out:
#        Names  Physics  Maths
# John    John       40     75
# Abdul  Abdul       60     90

# %% [markdown]
# ### We get error

# %%
scores_df.iloc[[1:3]]
# Out:
#   File "<ipython-input-34-8db13dad6495>", line 1
#     scores_df.iloc[[1:3]]
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Ind Ex:8 Slicing, fetch only the first and fourth row details

# %%
scores_df.iloc[[0,3],[1,2]]
# Out:
#       Physics  Maths
# Ram        45     60
# Siva       80     65

# %% [markdown]
# ### Ind Ex:9 Index based row slicing

# %%
scores_df.iloc[0:5]          # Row from 1st to 6th
# Out:
#        Names  Physics  Maths
# Ram      Ram       45     60
# John    John       40     75
# Abdul  Abdul       60     90
# Siva    Siva       80     65
# Adam    Adam       90     80

# %% [markdown]
# ### Ind Ex:10 Index based row and column slicing

# %%
scores_df.iloc[1:4,0:2]
# Out:
#        Names  Physics
# John    John       40
# Abdul  Abdul       60
# Siva    Siva       80

# %% [markdown]
# ### Ind Ex:11 Adding rows using loc
#
# #### Add a columns or a row

# %%
scores_df
# Out:
#          Names  Physics  Maths
# Ram        Ram       45     60
# John      John       40     75
# Abdul    Abdul       60     90
# Siva      Siva       80     65
# Adam      Adam       90     80
# Rahman  Rahman       75     60

# %% [markdown]
# #### Creating new column

# %%
scores_df['Class']="Tenth"       # Single values to all the rows
scores_df
# Out:
#          Names  Physics  Maths  Class
# Ram        Ram       45     60  Tenth
# John      John       40     75  Tenth
# Abdul    Abdul       60     90  Tenth
# Siva      Siva       80     65  Tenth
# Adam      Adam       90     80  Tenth
# Rahman  Rahman       75     60  Tenth

# %%
scores_df['History']=[60,70,80,90,95,97]    # Multiple values to columns
scores_df
# Out:
#          Names  Physics  Maths  Class  History
# Ram        Ram       45     60  Tenth       60
# John      John       40     75  Tenth       70
# Abdul    Abdul       60     90  Tenth       80
# Siva      Siva       80     65  Tenth       90
# Adam      Adam       90     80  Tenth       95
# Rahman  Rahman       75     60  Tenth       97

# %%
scores_df.shape
# Out:
# (6, 5)

# %% [markdown]
# #### Adding new row

# %%
scores_df.loc['kumar']=['Kumar',80,70,'Ninth',60]
scores_df
# Out:
#          Names  Physics  Maths  Class  History
# Ram        Ram       45     60  Tenth       60
# John      John       40     75  Tenth       70
# Abdul    Abdul       60     90  Tenth       80
# Siva      Siva       80     65  Tenth       90
# Adam      Adam       90     80  Tenth       95
# Rahman  Rahman       75     60  Tenth       97
# kumar    Kumar       80     70  Ninth       60

# %%
# new column capital 'K'

# its case sensitive
scores_df.loc['Kumar']=['Kumar',80,70,60,'Ninth']    # Adding rows
scores_df
# Out:
#          Names  Physics  Maths  Class History
# Ram        Ram       45     60  Tenth      60
# John      John       40     75  Tenth      70
# Abdul    Abdul       60     90  Tenth      80
# Siva      Siva       80     65  Tenth      90
# Adam      Adam       90     80  Tenth      95
# Rahman  Rahman       75     60  Tenth      97
# kumar    Kumar       80     70  Ninth      60
# Kumar    Kumar       80     70     60   Ninth

# %% [markdown]
# ## IX. Sort

# %% [markdown]
# ### Ex:1 Sort the dataframe by index in ascending order

# %%
scores_df=scores_df.sort_index()  # by default ascending order
scores_df
# Out:
#          Names  Physics  Maths  Class History
# Abdul    Abdul       60     90  Tenth      80
# Adam      Adam       90     80  Tenth      95
# John      John       40     75  Tenth      70
# Kumar    Kumar       80     70     60   Ninth
# Rahman  Rahman       75     60  Tenth      97
# Ram        Ram       45     60  Tenth      60
# Siva      Siva       80     65  Tenth      90
# kumar    Kumar       80     70  Ninth      60

# %% [markdown]
# ### Ex:2 Sort the dataframe by index single column - Ascending order

# %%
scores_df.sort_values(by='Maths')
# Out:
#          Names  Physics  Maths  Class History
# Rahman  Rahman       75     60  Tenth      97
# Ram        Ram       45     60  Tenth      60
# Siva      Siva       80     65  Tenth      90
# Kumar    Kumar       80     70     60   Ninth
# kumar    Kumar       80     70  Ninth      60
# John      John       40     75  Tenth      70
# Adam      Adam       90     80  Tenth      95
# Abdul    Abdul       60     90  Tenth      80

# %% [markdown]
# ### Ex:3 Sort the dataframe by index single column - Descending order

# %%
scores_df.sort_values(by='Maths',ascending=0)
# Out:
#          Names  Physics  Maths  Class History
# Abdul    Abdul       60     90  Tenth      80
# Adam      Adam       90     80  Tenth      95
# John      John       40     75  Tenth      70
# Kumar    Kumar       80     70     60   Ninth
# kumar    Kumar       80     70  Ninth      60
# Siva      Siva       80     65  Tenth      90
# Rahman  Rahman       75     60  Tenth      97
# Ram        Ram       45     60  Tenth      60

# %% [markdown]
# ### Ex:4 Sort the dataframe by multiple columns

# %%
scores_df.sort_values(by=['Maths', 'Physics'],ascending=[True,False])
# Out:
#          Names  Physics  Maths  Class History
# Rahman  Rahman       75     60  Tenth      97
# Ram        Ram       45     60  Tenth      60
# Siva      Siva       80     65  Tenth      90
# Kumar    Kumar       80     70     60   Ninth
# kumar    Kumar       80     70  Ninth      60
# John      John       40     75  Tenth      70
# Adam      Adam       90     80  Tenth      95
# Abdul    Abdul       60     90  Tenth      80

# %%
scores_df.sort_values(by=['Maths', 'Physics'],ascending=[True,True])
# Out:
#          Names  Physics  Maths  Class History
# Ram        Ram       45     60  Tenth      60
# Rahman  Rahman       75     60  Tenth      97
# Siva      Siva       80     65  Tenth      90
# Kumar    Kumar       80     70     60   Ninth
# kumar    Kumar       80     70  Ninth      60
# John      John       40     75  Tenth      70
# Adam      Adam       90     80  Tenth      95
# Abdul    Abdul       60     90  Tenth      80

# %% [markdown]
# ## X. Rank

# %%
image_02 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_06/10.2.png")
display.display(image_02)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=854x637>

# %% [markdown]
# ### Ex:1 Create a rank column and pass the returned rank series
#
# **The rank() function is used to compute the rank of each value in the "Maths" column. It assigns a unique rank to each value based on their relative positions in the column, with ties being handled based on the method used (default is "average").**

# %%
scores_df["Maths_Rank"] = scores_df["Maths"].rank()
scores_df
# Out:
#          Names  Physics  Maths  Class History  Maths_Rank
# Abdul    Abdul       60     90  Tenth      80         8.0
# Adam      Adam       90     80  Tenth      95         7.0
# John      John       40     75  Tenth      70         6.0
# Kumar    Kumar       80     70     60   Ninth         4.5
# Rahman  Rahman       75     60  Tenth      97         1.5
# Ram        Ram       45     60  Tenth      60         1.5
# Siva      Siva       80     65  Tenth      90         3.0
# kumar    Kumar       80     70  Ninth      60         4.5

# %%
scores_df.sort_values(by='Maths',ascending=0,inplace = True)
scores_df          # descending order
# Out:
#          Names  Physics  Maths  Class History  Maths_Rank
# Abdul    Abdul       60     90  Tenth      80         8.0
# Adam      Adam       90     80  Tenth      95         7.0
# John      John       40     75  Tenth      70         6.0
# Kumar    Kumar       80     70     60   Ninth         4.5
# kumar    Kumar       80     70  Ninth      60         4.5
# Siva      Siva       80     65  Tenth      90         3.0
# Rahman  Rahman       75     60  Tenth      97         1.5
# Ram        Ram       45     60  Tenth      60         1.5

# %%
scores_df["Maths_Rank1"] = scores_df["Maths"].rank()
scores_df
# Out:
#          Names  Physics  Maths  Class History  Maths_Rank  Maths_Rank1
# Abdul    Abdul       60     90  Tenth      80         8.0          8.0
# Adam      Adam       90     80  Tenth      95         7.0          7.0
# John      John       40     75  Tenth      70         6.0          6.0
# Kumar    Kumar       80     70     60   Ninth         4.5          4.5
# kumar    Kumar       80     70  Ninth      60         4.5          4.5
# Siva      Siva       80     65  Tenth      90         3.0          3.0
# Rahman  Rahman       75     60  Tenth      97         1.5          1.5
# Ram        Ram       45     60  Tenth      60         1.5          1.5

# %% [markdown]
# ### Ex:2 Create a rank column and pass the returned rank series (rank in descending order)

# %%
scores_df["Maths_Rank2"] = scores_df["Maths"].rank(ascending=0)
scores_df
# Out:
#          Names  Physics  Maths  Class History  Maths_Rank  Maths_Rank1  \
# Abdul    Abdul       60     90  Tenth      80         8.0          8.0
# Adam      Adam       90     80  Tenth      95         7.0          7.0
# John      John       40     75  Tenth      70         6.0          6.0
# Kumar    Kumar       80     70     60   Ninth         4.5          4.5
# kumar    Kumar       80     70  Ninth      60         4.5          4.5
# Siva      Siva       80     65  Tenth      90         3.0          3.0
# Rahman  Rahman       75     60  Tenth      97         1.5          1.5
# Ram        Ram       45     60  Tenth      60         1.5          1.5
#
#         Maths_Rank2
# Abdul           1.0
# Adam            2.0
# John            3.0
# Kumar           4.5
# kumar           4.5
# Siva            6.0
# Rahman          7.5
# Ram             7.5

# %% [markdown]
# ### Ex:3 Create a rank column using 'min' method

# %%
scores_df["Maths_Rank3"] = scores_df["Maths"].rank(ascending=0,method='min')
scores_df
# Out:
#          Names  Physics  Maths  Class History  Maths_Rank  Maths_Rank1  \
# Abdul    Abdul       60     90  Tenth      80         8.0          8.0
# Adam      Adam       90     80  Tenth      95         7.0          7.0
# John      John       40     75  Tenth      70         6.0          6.0
# Kumar    Kumar       80     70     60   Ninth         4.5          4.5
# kumar    Kumar       80     70  Ninth      60         4.5          4.5
# Siva      Siva       80     65  Tenth      90         3.0          3.0
# Rahman  Rahman       75     60  Tenth      97         1.5          1.5
# Ram        Ram       45     60  Tenth      60         1.5          1.5
#
#         Maths_Rank2  Maths_Rank3
# Abdul           1.0          1.0
# Adam            2.0          2.0
# John            3.0          3.0
# Kumar           4.5          4.0
# kumar           4.5          4.0
# Siva            6.0          6.0
# Rahman          7.5          7.0
# Ram             7.5          7.0

# %% [markdown]
# ### Ex:4 Create a rank column using 'dense' method
#
# **The rank() function is used to compute the ranks. The additional parameters are:**
#
# ascending=0: This parameter specifies that the ranking should be in descending order. In other words, the highest values will have the lowest rank (1 for the highest value). method='dense': This parameter specifies the method for handling ties (when multiple values are the same). The 'dense' method assigns the same rank to tied values and then increments the rank by 1 for the next distinct value.

# %%
scores_df["Maths_Rank4"] = scores_df["Maths"].rank(ascending=0,method='dense')
scores_df
# Out:
#          Names  Physics  Maths  Class History  Maths_Rank  Maths_Rank1  \
# Abdul    Abdul       60     90  Tenth      80         8.0          8.0
# Adam      Adam       90     80  Tenth      95         7.0          7.0
# John      John       40     75  Tenth      70         6.0          6.0
# Kumar    Kumar       80     70     60   Ninth         4.5          4.5
# kumar    Kumar       80     70  Ninth      60         4.5          4.5
# Siva      Siva       80     65  Tenth      90         3.0          3.0
# Rahman  Rahman       75     60  Tenth      97         1.5          1.5
# Ram        Ram       45     60  Tenth      60         1.5          1.5
#
#         Maths_Rank2  Maths_Rank3  Maths_Rank4
# Abdul           1.0          1.0          1.0
# Adam            2.0          2.0          2.0
# John            3.0          3.0          3.0
# Kumar           4.5          4.0          4.0
# kumar           4.5          4.0          4.0
# Siva            6.0          6.0          5.0
# ...

# %% [markdown]
# ## VIII Reading data from various sources.

# %% [markdown]
# 1. CSV = pd.read_csv('train.csv')
#
# 2. XLSX files = pd.read_excel('train.xlsx', sheetname = 'Invoice')
#
#
# 3. ZIP files =
#            * import zipfile
#            * archive = zipfile.ZipFile('T.zip', 'r')
#            * df = archive.read('train.csv')
#
# 4. Text (txt) =
#           * text_file = open("text.txt", "r")
#           * lines = text_file.read()
#
# 5. JSON file = pd.read_json('train.json')
#
# 6. XML file =
#             * import xml.etree.ElementTree as ET
#             * tree = ET.parse('train.xml')
#             * root = tree.getroot()
#             * print root.tag
#
# 7. HDF =  pd.read_hdf('train.h5')

# %% [markdown]
# ### Read the mtcars.csv

# %%
# About the dataset:(Motor Trend US Magazine)
Data = pd.read_csv('/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Note_books/Week_06/Day_10_Data/mtcars.csv')
Data.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
#exl=pd.read_excel('Book1.xlsx')
#exl

# %% [markdown]
# # Pandas - Part II

# %% [markdown]
# ## I. Concatenate
# **concat() function does all of the heavy lifting of performing concatenation operations along an axis while performing optional set logic (union or intersection) of the indexes (if any) on the other axes.**

# %%
image_03 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_06/10.3.png")
display.display(image_03)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=858x639>

# %% [markdown]
# ### Series Ex:1 Combine DataFrame objects

# %%
Table1 = pd.DataFrame({'A': ['10', '11', '12', '13'],
                   'B': ['20', '21', '22', '23'],
                   'C': ['30', '31', '32', '33'],
                   'D': ['40', '41', '42', '43']},
                   index=[0, 1, 2, 3])
Table1
# Out:
#     A   B   C   D
# 0  10  20  30  40
# 1  11  21  31  41
# 2  12  22  32  42
# 3  13  23  33  43

# %%
Table2 = pd.DataFrame({'A': ['14', '15', '16', '17'],
                   'B': ['24', '25', '26', '27'],
                   'C': ['34', '35', '36', '37'],
                   'D': ['44', '45', '46', '47']},
                   index=[4, 5, 6, 7])
Table2
# Out:
#     A   B   C   D
# 4  14  24  34  44
# 5  15  25  35  45
# 6  16  26  36  46
# 7  17  27  37  47

# %%
Table3 = pd.DataFrame({'A': ['18', '19'],
                   'B': ['28', '29'],
                   'C': ['38', '39'],
                   'D': ['48', '49']},
                  index=[8, 9])
Table3
# Out:
#     A   B   C   D
# 8  18  28  38  48
# 9  19  29  39  49

# %%
df = [Table1, Table2, Table3]
df
# Out:
# [    A   B   C   D
#  0  10  20  30  40
#  1  11  21  31  41
#  2  12  22  32  42
#  3  13  23  33  43,
#      A   B   C   D
#  4  14  24  34  44
#  5  15  25  35  45
#  6  16  26  36  46
#  7  17  27  37  47,
#      A   B   C   D
#  8  18  28  38  48
#  9  19  29  39  49]

# %%
pd.concat(df, axis=0, join='outer', ignore_index=False,
         keys=None, levels=None, names=None, verify_integrity=False,
         copy=True)
# Out:
#     A   B   C   D
# 0  10  20  30  40
# 1  11  21  31  41
# 2  12  22  32  42
# 3  13  23  33  43
# 4  14  24  34  44
# 5  15  25  35  45
# 6  16  26  36  46
# 7  17  27  37  47
# 8  18  28  38  48
# 9  19  29  39  49

# %%
image_04 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_06/10.4.png")
display.display(image_04)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=794x757>

# %%
Data = pd.concat([Table1, Table2, Table3])
Data
# Out:
#     A   B   C   D
# 0  10  20  30  40
# 1  11  21  31  41
# 2  12  22  32  42
# 3  13  23  33  43
# 4  14  24  34  44
# 5  15  25  35  45
# 6  16  26  36  46
# 7  17  27  37  47
# 8  18  28  38  48
# 9  19  29  39  49

# %% [markdown]
# ### Concat Ex:2 Adding hierarchical index

# %%
pd.concat(df, keys=['x', 'y', 'z'])
# Out:
#       A   B   C   D
# x 0  10  20  30  40
#   1  11  21  31  41
#   2  12  22  32  42
#   3  13  23  33  43
# y 4  14  24  34  44
#   5  15  25  35  45
#   6  16  26  36  46
#   7  17  27  37  47
# z 8  18  28  38  48
#   9  19  29  39  49

# %% [markdown]
# ### Series Ex:3 Combine DataFrames with overlapping columns and return only those that are shared

# %%
Output = pd.concat([Table1, Table2], axis=1, join='inner')         #,join_axes=[df1.index]
Output
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, A, B, C, D]
# Index: []

# %%
Output = pd.concat([Table1, Table2], axis=1)
Output
# Out:
#      A    B    C    D    A    B    C    D
# 0   10   20   30   40  NaN  NaN  NaN  NaN
# 1   11   21   31   41  NaN  NaN  NaN  NaN
# 2   12   22   32   42  NaN  NaN  NaN  NaN
# 3   13   23   33   43  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN   14   24   34   44
# 5  NaN  NaN  NaN  NaN   15   25   35   45
# 6  NaN  NaN  NaN  NaN   16   26   36   46
# 7  NaN  NaN  NaN  NaN   17   27   37   47

# %%
Output = pd.concat([Table1, Table2], axis=1)
Output
# Out:
#      A    B    C    D    A    B    C    D
# 0   10   20   30   40  NaN  NaN  NaN  NaN
# 1   11   21   31   41  NaN  NaN  NaN  NaN
# 2   12   22   32   42  NaN  NaN  NaN  NaN
# 3   13   23   33   43  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN   14   24   34   44
# 5  NaN  NaN  NaN  NaN   15   25   35   45
# 6  NaN  NaN  NaN  NaN   16   26   36   46
# 7  NaN  NaN  NaN  NaN   17   27   37   47

# %% [markdown]
# ## II. Merge

# %%
image_05 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_06/10.5.png")
display.display(image_05)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=854x560>

# %%
left_frame = pd.DataFrame({'key': range(5),
                          'left_value': ['a', 'b', 'c', 'd', 'e']})
left_frame
# Out:
#    key left_value
# 0    0          a
# 1    1          b
# 2    2          c
# 3    3          d
# 4    4          e

# %%
right_frame = pd.DataFrame({'key': range(2, 7),
                          'right_value': ['f', 'g', 'h', 'i', 'j']})
right_frame
# Out:
#    key right_value
# 0    2           f
# 1    3           g
# 2    4           h
# 3    5           i
# 4    6           j

# %% [markdown]
# ### Inner Join

# %%
image_06 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_06/10.6.png")
display.display(image_06)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=845x551>

# %%
left_frame
# Out:
#    key left_value
# 0    0          a
# 1    1          b
# 2    2          c
# 3    3          d
# 4    4          e

# %%
right_frame
# Out:
#    key right_value
# 0    2           f
# 1    3           g
# 2    4           h
# 3    5           i
# 4    6           j

# %%
pd.merge(left_frame, right_frame, on='key', how='inner')
# Out:
#    key left_value right_value
# 0    2          c           f
# 1    3          d           g
# 2    4          e           h

# %% [markdown]
# ### Outer Join

# %%
image_07 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_06/10.7.png")
display.display(image_07)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=850x560>

# %%
pd.merge(left_frame, right_frame, on='key', how='outer')
# Out:
#    key left_value right_value
# 0    0          a         NaN
# 1    1          b         NaN
# 2    2          c           f
# 3    3          d           g
# 4    4          e           h
# 5    5        NaN           i
# 6    6        NaN           j

# %% [markdown]
# ### Right Join

# %%
image_08 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_06/10.8.png")
display.display(image_08)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=852x549>

# %%
pd.merge(left_frame, right_frame, on='key', how='right')
# Out:
#    key left_value right_value
# 0    2          c           f
# 1    3          d           g
# 2    4          e           h
# 3    5        NaN           i
# 4    6        NaN           j

# %% [markdown]
# ### Left Join

# %%
image_09 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_06/10.9.png")
display.display(image_09)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=846x560>

# %%
pd.merge(left_frame, right_frame, on='key', how='left')
# Out:
#    key left_value right_value
# 0    0          a         NaN
# 1    1          b         NaN
# 2    2          c           f
# 3    3          d           g
# 4    4          e           h

# %% [markdown]
# ## III. Reshape:
#
# 1. stack
# 2. unstack
# 3. melt

# %% [markdown]
# **Create multiple header dataframe:**

# %%
header = pd.MultiIndex.from_product([['3_Months','6_Months'],['Python','ML']])
d=([[12,45,67,56],[78,89,45,67],[45,67,89,90],[67,44,56,55]])

# %%
df = pd.DataFrame(d,
                 index=['Jony','Anil','Sunil','Rocky'],
                 columns=header)
df
# Out:
#       3_Months     6_Months
#         Python  ML   Python  ML
# Jony        12  45       67  56
# Anil        78  89       45  67
# Sunil       45  67       89  90
# Rocky       67  44       56  55

# %% [markdown]
# ## IV. Stack

# %%
image_10 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_06/10.10.png")
display.display(image_10)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=849x586>

# %% [markdown]
# **Note:** Stack() Function in dataframe stacks the column to rows at level 1 (default).

# %% [markdown]
# ### Stack Ex:1

# %%
df
# Out:
#       3_Months     6_Months
#         Python  ML   Python  ML
# Jony        12  45       67  56
# Anil        78  89       45  67
# Sunil       45  67       89  90
# Rocky       67  44       56  55

# %%
stacked_df=df.stack()
stacked_df
# Out:
#               3_Months  6_Months
# Jony  ML            45        56
#       Python        12        67
# Anil  ML            89        67
#       Python        78        45
# Sunil ML            67        90
#       Python        45        89
# Rocky ML            44        55
#       Python        67        56

# %%
stacked_df=df.stack(level=1)
stacked_df
# Out:
#               3_Months  6_Months
# Jony  ML            45        56
#       Python        12        67
# Anil  ML            89        67
#       Python        78        45
# Sunil ML            67        90
#       Python        45        89
# Rocky ML            44        55
#       Python        67        56

# %% [markdown]
# ### Stack Ex:2
#
# stack(level=0)

# %%
stacked_df=df.stack(level=0)
stacked_df
# Out:
#                 ML  Python
# Jony  3_Months  45      12
#       6_Months  56      67
# Anil  3_Months  89      78
#       6_Months  67      45
# Sunil 3_Months  67      45
#       6_Months  90      89
# Rocky 3_Months  44      67
#       6_Months  55      56

# %% [markdown]
# ### Stack Ex:3
#
# stack(level=1)

# %%
stacked_df=df.stack()
stacked_df
# Out:
#               3_Months  6_Months
# Jony  ML            45        56
#       Python        12        67
# Anil  ML            89        67
#       Python        78        45
# Sunil ML            67        90
#       Python        45        89
# Rocky ML            44        55
#       Python        67        56

# %% [markdown]
# ## V. Unstack
#
# **unstack() Function in dataframe unstacks the row to columns . Basically it’s a reverse of stacking**

# %%
image_11 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_06/10.11.png")
display.display(image_11)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=854x585>

# %%
# unstack the dataframe

unstacked_df = stacked_df.unstack()
unstacked_df
# Out:
#       3_Months        6_Months
#             ML Python       ML Python
# Anil        89     78       67     45
# Jony        45     12       56     67
# Rocky       44     67       55     56
# Sunil       67     45       90     89

# %% [markdown]
# ## VI. Melt

# %%
image_12 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_06/10.12.png")
display.display(image_12)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=847x578>

# %% [markdown]
# **The pd.melt() function in the Pandas library is used to transform or reshape a DataFrame from a wide format to a long format. It's a useful tool when you want to restructure your data to make it more suitable for certain types of analysis, visualization, or modeling. Here are some common use cases for using pd.melt().**

# %%
data = pd.DataFrame({
   'Name': ['Alice', 'Bob', 'Charlie'],
   'Math_Score': [90, 85, 78],
   'English_Score': [88, 76, 92],
   'History_Score': [75, 82, 89]
})
data
# Out:
#       Name  Math_Score  English_Score  History_Score
# 0    Alice          90             88             75
# 1      Bob          85             76             82
# 2  Charlie          78             92             89

# %% [markdown]
# **we've melted the original DataFrame, converting it from a wide format with subject-specific columns to a long format where each row represents a student, their subject, and their score. This long format can be more suitable for various types of analysis and visualization.**

# %%
melted_data = pd.melt(data, id_vars=['Name'], var_name='Subject', value_name='Score')
melted_data
# Out:
#       Name        Subject  Score
# 0    Alice     Math_Score     90
# 1      Bob     Math_Score     85
# 2  Charlie     Math_Score     78
# 3    Alice  English_Score     88
# 4      Bob  English_Score     76
# 5  Charlie  English_Score     92
# 6    Alice  History_Score     75
# 7      Bob  History_Score     82
# 8  Charlie  History_Score     89

# %% [markdown]
# ### Ex- 02

# %%
data = {
   "location":['Bangalore', 'Chennai'],
   "Temperature" : ["Predict", "Actual"],
   "Jan-2019":[30, 32],
   "Feb-2019":[45, 43],
   "Mar-2019":[24, 22]
}
df = pd.DataFrame(data, columns=['location', 'Temperature','Jan-2019', 'Feb-2019', 'Mar-2019'])
print(df)
# Out:
#     location Temperature  Jan-2019  Feb-2019  Mar-2019
# 0  Bangalore     Predict        30        45        24
# 1    Chennai      Actual        32        43        22

# %%
df2 = pd.melt(df, id_vars=["location", "Temperature"], var_name="Date", value_name="Value")
print(df2)
# Out:
#     location Temperature      Date  Value
# 0  Bangalore     Predict  Jan-2019     30
# 1    Chennai      Actual  Jan-2019     32
# 2  Bangalore     Predict  Feb-2019     45
# 3    Chennai      Actual  Feb-2019     43
# 4  Bangalore     Predict  Mar-2019     24
# 5    Chennai      Actual  Mar-2019     22

# %% [markdown]
# ## VII. Pivot Table

# %%
#Create a DataFrame

d = {
   'Name':['Jony','Anil','Sunil','Jony','Anil','Rocky',
           'Jony','Anil','Sunil','Jony','Anil','Rocky'],
   'Exam_Months':['3_Months','3_Months','3_Months','3_Months','3_Months','3_Months',
           '6_Months','6_Months','6_Months','6_Months','6_Months','6_Months'],

   'Subject':['Python','Python','SQL','SQL','ML','ML',
              'Python','Python','SQL','SQL','ML','ML'],
  'Score':[62,47,55,74,31,77,85,63,42,67,89,81]}
df = pd.DataFrame(d,columns=['Name','Exam_Months','Subject','Score'])
df
# Out:
#      Name Exam_Months Subject  Score
# 0    Jony    3_Months  Python     62
# 1    Anil    3_Months  Python     47
# 2   Sunil    3_Months     SQL     55
# 3    Jony    3_Months     SQL     74
# 4    Anil    3_Months      ML     31
# 5   Rocky    3_Months      ML     77
# 6    Jony    6_Months  Python     85
# 7    Anil    6_Months  Python     63
# 8   Sunil    6_Months     SQL     42
# 9    Jony    6_Months     SQL     67
# 10   Anil    6_Months      ML     89
# 11  Rocky    6_Months      ML     81

# %% [markdown]
# **The pivot() function in Pandas is used to reshape a DataFrame from a long or tidy format into a wide format, where the rows and columns are reorganized to create a new structure of the data. It is essentially the opposite of the melt() function. The primary purpose of pivot() is to pivot data for better analysis, reporting, or presentation.**

# %%
image_13 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_06/10.13.png")
display.display(image_13)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=850x608>

# %% [markdown]
# ### Pivot Ex:1 Create pivot table with aggregate function mean

# %%
pd.pivot_table(df, index=['Exam_Months','Subject'], aggfunc='mean')
# Out:
# <ipython-input-97-c75a9c427e00>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(df, index=['Exam_Months','Subject'], aggfunc='mean')
#                      Score
# Exam_Months Subject
# 3_Months    ML        54.0
#             Python    54.5
#             SQL       64.5
# 6_Months    ML        85.0
#             Python    74.0
#             SQL       54.5

# %% [markdown]
# ### Pivot Ex:2 Create pivot table with aggregate function sum

# %%
pd.pivot_table(df, index=['Name','Subject'], aggfunc='sum')
# Out:
# <ipython-input-98-293915e19189>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(df, index=['Name','Subject'], aggfunc='sum')
#                Score
# Name  Subject
# Anil  ML         120
#       Python     110
# Jony  Python     147
#       SQL        141
# Rocky ML         158
# Sunil SQL         97

# %% [markdown]
# ## VIII. Duplicate

# %%
#Create a DataFrame
d = {
   'Name':['Jony','Anil','Sunil','Jony','Anil','Rocky',
           'Jony','Anil','Sunil','Jony','Anil','Rocky'],
   'Exam_Months':['3_Months','3_Months','6_Months','3_Months','3_Months','3_Months',
           '3_Months','6_Months','6_Months','6_Months','6_Months','6_Months'],

   'Subject':['Python','Python','SQL','SQL','ML','ML',
              'Python','Python','SQL','SQL','ML','ML'],
  'Score':[62,47,42,74,31,77,62,63,42,67,89,81]}
df = pd.DataFrame(d,columns=['Name','Exam_Months','Subject','Score'])
df
# Out:
#      Name Exam_Months Subject  Score
# 0    Jony    3_Months  Python     62
# 1    Anil    3_Months  Python     47
# 2   Sunil    6_Months     SQL     42
# 3    Jony    3_Months     SQL     74
# 4    Anil    3_Months      ML     31
# 5   Rocky    3_Months      ML     77
# 6    Jony    3_Months  Python     62
# 7    Anil    6_Months  Python     63
# 8   Sunil    6_Months     SQL     42
# 9    Jony    6_Months     SQL     67
# 10   Anil    6_Months      ML     89
# 11  Rocky    6_Months      ML     81

# %% [markdown]
# ### Drop Ex:1 Drop the duplicates

# %%
Data = df.drop_duplicates()
Data
# Out:
#      Name Exam_Months Subject  Score
# 0    Jony    3_Months  Python     62
# 1    Anil    3_Months  Python     47
# 2   Sunil    6_Months     SQL     42
# 3    Jony    3_Months     SQL     74
# 4    Anil    3_Months      ML     31
# 5   Rocky    3_Months      ML     77
# 7    Anil    6_Months  Python     63
# 9    Jony    6_Months     SQL     67
# 10   Anil    6_Months      ML     89
# 11  Rocky    6_Months      ML     81

# %% [markdown]
# ### Drop Ex:2 Drop duplicate by a column name

# %%
df.drop_duplicates(['Name'], keep='last')
# Out:
#      Name Exam_Months Subject  Score
# 8   Sunil    6_Months     SQL     42
# 9    Jony    6_Months     SQL     67
# 10   Anil    6_Months      ML     89
# 11  Rocky    6_Months      ML     81

# %%
df.drop_duplicates(['Name'], keep='first')
# Out:
#     Name Exam_Months Subject  Score
# 0   Jony    3_Months  Python     62
# 1   Anil    3_Months  Python     47
# 2  Sunil    6_Months     SQL     42
# 5  Rocky    3_Months      ML     77

# %% [markdown]
# **Note:** Now let's drop the rows by column name. Rows are dropped in such a way that unique column value is retained for that column as shown below

# %% [markdown]
# ### Drop Ex:3 Drop duplicate in a csv file

# %%
df = pd.read_csv("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Note_books/Week_06/Day_10_Data/Humidity1.csv")
df
# Out:
#          date      city  temperature  humidity
# 0  05-01-2017  new york           65        56
# 1  05-01-2017  new york           61        54
# 2  05-02-2017  new york           70        60
# 3  05-02-2017  new york           71        62
# 4  05-01-2017    mumbai           75        80
# 5  05-01-2017    mumbai           78        83
# 6  05-02-2017    mumbai           82        85
# 7  05-02-2017    mumbai           80        26

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %% [markdown]
# **False means no duplication. We checked for the entire row. None of the row is matching with each other completely.
# Lets check for the duplication in certain columns**

# %%
df.duplicated(['date'])
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# dtype: bool

# %% [markdown]
# **Lets check for the duplication in two columns together?**

# %%
df.duplicated(['date','city'])
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# dtype: bool

# %%
df.duplicated(['date','city'], keep='last')
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# dtype: bool

# %% [markdown]
# **Keep**= last will throw false when the row is repeated from second time.

# %% [markdown]
# **Lets drop duplicates by considering city**

# %%
df.drop_duplicates(['city'])
# Out:
#          date      city  temperature  humidity
# 0  05-01-2017  new york           65        56
# 4  05-01-2017    mumbai           75        80
