# %%
import IPython.display as display
from PIL import Image

# %% [markdown]
# ## Python Operators

# %%
image_01 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_02/3.1.png")
display.display(image_01)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1030x516>

# %% [markdown]
# ## 1. Arithmetic Operators

# %%
image_02 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_02/3.2.png")
display.display(image_02)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1340x551>

# %% [markdown]
# #### The most common arithmetic Operators are
#
# (Addition) ---------------------- +
#
# (Subtraction) ------------------- -
#
# (Multiplication) ---------------- *
#
# (Division) ---------------------- /
#
# (Modulus) ---------------------- %

# %% [markdown]
# ### 1. + Addition Operator

# %%
# Adding two Variables which has a int values
A = 30
B = 20
C = A+B
print(C)
print(type(C))
# Out:
# 50
# <class 'int'>

# %%
# Adding two Variables which has a int and float values
a = 4 + 3.2
print(a)
print(type(a))
# Out:
# 7.2
# <class 'float'>

# %% [markdown]
# ### Addition with string variable

# %%
# Adding two strings
a = 'Technical' + 'Seek'
print(a)
print(type(a))
# Out:
# TechnicalSeek
# <class 'str'>

# %%
# Adding the "Strings" + '4'
a = 'Technical' + 'Seek' +'4' # here 4 is string
a
# Out:
# 'TechnicalSeek4'

# %%
# Adding the "Strings" + 4
a = 'Technical' + 'Seek' + 4 # here 4 is integer
a

# we cannot add a string with numbers and so it will throw an error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-56a4d75b97c5> in <cell line: 2>()
#       1 # Adding the "Strings" + 4
# ----> 2 a = 'Technical' + 'Seek' + 4 # here 4 is integer
#       3 a
#       4
#       5 # we cannot add a string with numbers and so it will throw an error
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ### 2. - subtraction Operator

# %%
# subtracting two Variables
A = 30
B = 20
C = A-B
print(C)
print(type(C))
# Out:
# 10
# <class 'int'>

# %%
# subtracting the multiple values which is int
a = 4 - 3 - 4
print(a)
print(type(a))
# Out:
# -3
# <class 'int'>

# %%
# subtracting the multiple values with int and float
a = 14 - 2.6 - 4

print(a)
print(type(a))
# Out:
# 7.4
# <class 'float'>

# %%
# subtract 2 string
a = "guvi"
b = "Hello Python"
c = a-b
print(c)

# note: we cannot subtract 2 strings
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-4eb375200940> in <cell line: 4>()
#       2 a = "guvi"
#       3 b = "Hello Python"
# ----> 4 c = a-b
#       5 print(c)
#       6
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# ### 3. * - Multiplication Operator

# %%
# Multiply two Variables both the values are integer
A = 30
B = 20
C = A*B
print(C)
print(type(C))
# Out:
# 600
# <class 'int'>

# %%
# Multiply two Variables  the values are integer and float
A = 30
B = 20.5
C = A*B
print(C)
print(type(C))
# Out:
# 615.0
# <class 'float'>

# %%
# Multiply string with number , data gets repeated
a = '3' * 3
a
# Out:
# '333'

# %%
# Multiplication of 2 string is not possible

a = "guvi"
b = "hello python"
c= a*b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-637d6506793d> in <cell line: 5>()
#       3 a = "guvi"
#       4 b = "hello python"
# ----> 5 c= a*b
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# ### 4. / - Division Operator

# %%
# Division using 2 variables and both the values are integer
a = 27
b = 2
c = a / b
print(c)
print(type(c))

# note : though both the inputs are int, division output will be always float
# Out:
# 13.5
# <class 'float'>

# %%
# Division using 2 variables and  values are integer and float
a = 27
b = 2.0
c = a / b
print(c)
print(type(c))

# note : though both the inputs are int, division output will be always float
# Out:
# 13.5
# <class 'float'>

# %%
# Division using 2 variables and  values are integer string
a = "Hello Python"
b = 2.0
c = a / b
print(c)
print(type(c))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-0241f7b80e36> in <cell line: 4>()
#       2 a = "Hello Python"
#       3 b = 2.0
# ----> 4 c = a / b
#       5 print(c)
#       6 print(type(c))
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %% [markdown]
# ### 5. // (Division Operators)

# %%
a = 29
b = 2
c = a//b
c

# Note : returns the quotient with integer as value
# Out:
# 14

# %%
a = 27.5
b = 2
c = a // b
c

# Note : returns the quotient with float value, but still it take the integer value
# Out:
# 13.0

# %% [markdown]
# ### 6. % Modulus

# %%
# Modulus - Find the remainder
A = 9
B = 4
C = A % B
C
# Out:
# 1

# %%
A = 35
B = 20
C = A % B
C
# Out:
# 15

# %% [markdown]
# ### Special Arithmetic Operators:
# // - (Division Operators)
#
# ** - (Square)

# %%
# Division Operators
A = 30.5
B = 20
C = A // B
C
# Out:
# 1.0

# %%
# Square
A = 5
B = 3
C = A ** B
C
# Out:
# 125

# %%
A=9
B=2
c=A**B
print(c)
# Out:
# 81

# %% [markdown]
# ###  Practice

# %%
## find the Squared output
x = 10
out = x*x
print("squared output :", out)
# Out:
# squared output : 100

# %%
## find the power
x = 10
out = x**x
print("power output :", out)
# Out:
# power output : 10000000000

# %% [markdown]
# ## Run time variable

# %%
nm = input("enter your name")
print("Welcome !!!", nm)
# Out:
# enter your named
# Welcome !!! d

# %%
type(nm)
# default data type of nm variable is string
# Out:
# str

# %%
# Get 2 variable in run time and add it
A = input('Please enter first vale :')   #string
B = input('Please enter second value')   #string
out = A + B
out
# Out:
# Please enter first vale :Dee
# Please enter second valueDD
# 'DeeDD'

# %% [markdown]
# Inference : the output is not added but concatenated
#
# Reason is, the input variable by default is string and not int
# Arithmetic Operators Problem:
# Step 1: Assign value to A=22 and B=33
#
# Step 2: Add value of A and B (22+33=55)
#
# Step 3: To this result add A to the output of Step 2 ( 55+22)
#
# Step 4: It will print the final result as 77

# %%
A = input()
B = input()
result = A + B

print("Addition of runtime variables are : ", result)

# note :  by default the run time parameter is string datatype.
# instead of addition, concatenation is done because input is string data type
# Out:
# 6
# 4
# Addition of runtime variables are :  64

# %%
A = int(input())     # A is converted in to integer
B = int(input())     # B is converted in to integer
result = A + B

print("Addition of runtime variables are : ", result)
# Out:
# 6
# 4
# Addition of runtime variables are :  10

# %%
A = input()    # A is string
B = int(input())     # B is converted in to integer
result = A + B

print("Addition of runtime variables are : ", result)
# Out:
# 4
# 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-0999b0d1bd94> in <cell line: 3>()
#       1 A = input()    # A is string
#       2 B = int(input())     # B is converted in to integer
# ----> 3 result = A + B
#       4
#       5 print("Addition of runtime variables are : ", result)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# pass the input 10, 10.5.
# both the input are int - type casting, one of the input has to be flaot
A = int(input())
B = int(input())
result = A + B

print("Addition of runtime variables are : ", result)
# Out:
# 3
# 3.6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-617a56c53ef3> in <cell line: 4>()
#       2 # both the input are int - type casting, one of the input has to be flaot
#       3 A = int(input())
# ----> 4 B = int(input())
#       5 result = A + B
#       6
#
# ValueError: invalid literal for int() with base 10: '3.6'

# %%
A = int(input())
B = float(input())
result = A + B

print("Addition of runtime variables are : ", result)
# Out:
# 3
# 3.6
# Addition of runtime variables are :  6.6

# %% [markdown]
# ##2. Relation Operator - Out will be boolean

# %%
image_03 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_02/3.3.png")
display.display(image_03)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1340x551>

# %%
x = 100
y = 12

# %%
# Output: x > y is True
print('x > y  is',x>y)
# Out:
# x > y  is True

# %%
# x < y  is False
print('x < y  is',x<y)
# Out:
# x < y  is False

# %%
#x == y is False
print('x == y is',x==y)
# Out:
# x == y is False

# %%
# Output: x != y is True
print('x != y is',x!=y)
# Out:
# x != y is True

# %%
# x >= y is True
print('x >= y is',x>=y)
# Out:
# x >= y is True

# %%
# Output: x <= y is False
print('x <= y is',x<=y)
# Out:
# x <= y is False

# %% [markdown]
# ## 3. Logical Operators - Output will be in Boolean

# %%
image_04 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_02/3.4.png")
display.display(image_04)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1340x551>

# %% [markdown]
# ### 1.And Operator

# %%
image_05 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_02/3.5.png")
display.display(image_05)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1340x551>

# %%
x = True
y = False

# %%
# Output: x and y is False
print('x and y is',x and y)
# Out:
# x and y is False

# %%
x=True
y=True
print(x and y)
# Out:
# True

# %%
x=False
y=False
print(x and y)
# Out:
# False

# %% [markdown]
# ### 2. OR Operator

# %%
image_06 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_02/3.6.png")
display.display(image_06)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1340x551>

# %%
x = True
y = False

# Output: x or y is True
print('x or y is',x or y)
# Out:
# x or y is True

# %% [markdown]
# ### 3. NOT Operator

# %%
image_07 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_02/3.7.png")
display.display(image_07)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1340x551>

# %%
x = True
y = False

# Output: not x is False
print('Not x is : ',not x)
# Out:
# Not x is :  False

# %%
print(not y)
# Out:
# True

# %% [markdown]
# ### 4. Bitwise Operators

# %%
image_08 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_02/3.8.png")
display.display(image_08)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1340x551>

# %%
a=10 # binary 1010
b=7  # binary 0111
print(a&b)
# Out:
# 2

# %%
a=20
b=17
print(a|b)
# Out:
# 21

# %%
a=60
b=17
print(a^b)
# Out:
# 45

# %%
a = 20
print(~a)
# Out:
# -21

# %%
a=50
print(a<<1)
# Out:
# 100

# %%
print(a>>1)
# Out:
# 10

# %% [markdown]
# ### 5. Assignment Operation

# %%
image_09 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_02/3.9.png")
display.display(image_09)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1340x551>

# %%
# Addition
a=3
b=4

a+=b
#a = a+b # above code is as same as this line

print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: 7
# b: 4

# %%
# Addition
a=3
b=4

a+=b
#a = a+b # above code is as same as this line

print("a: ",a)
print("b: ",b)
#print(type(a))
# Out:
# a:  7
# b:  4

# %%
# Subtraction
a=3
b=4

a-=b


print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: -1
# b: 4

# %%
# Multiplication
a=3
b=4

a*=b

print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: 12
# b: 4

# %%
# Division
a=3
b=4

a/=b

print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: 0.75
# b: 4

# %%
# Modulus
a=3
b=4

a%=b

print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: 3
# b: 4

# %%
#Exponentiation
a=3
b=4

a**=b

print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: 81
# b: 4

# %%
# Floor Division
a=3
b=4

a//=b

print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: 0
# b: 4

# %% [markdown]
# ## Concatenate

# %% [markdown]
# ### 1.Concatenating and Joining Strings

# %%
'a' + 'b' + 'c'
# Out:
# 'abc'

# %%
'do' * 3
# Out:
# 'dododo'

# %% [markdown]
# ### 2. Concatenating With .Join()

# %%
strings = ['do', 're', 'mi']
' , '.join(strings)
# Out:
# 'do , re , mi'

# %%
strings = ['do', 're', 'mi']
' # '.join(strings)
# Out:
# 'do # re # mi'

# %% [markdown]
#  ### Multiple ways of printing the statement

# %%
first = 10
second = 20
print ("First number is", first, "and second number is", second)
# Out:
# First number is 10 and second number is 20

# %%
first = 10
second = 20
print ("First number is {}  and second number is {}".format(first,second))
# Out:
# First number is 10  and second number is 20

# %%
first = 10.234556
second = 20.432111

## type cast the float into int while printing
print("first value : %d ,second :  %d \n" %(first,second))
# Out:
# first value : 10 ,second :  20

# %%
first = 10.234556
second = 20.432111

## print the variable as is
print("first value : %f ,second :  %f \n" %(first,second))
# Out:
# first value : 10.234556 ,second :  20.432111

# %%
first = 10.234556
second = 20.432111

## restrict the float to 3 deigits
print("first value : %0.3f ,second :  %0.3f " %(first,second))
# Out:
# first value : 10.235 ,second :  20.432

# %%
# print the code with specific delimiter
print(1, 2, 3, 4, sep=' # ')
# Out:
# 1 # 2 # 3 # 4

# %% [markdown]
# ### length

# %%
a = "Hi guvi"

print('a length is', len(a)) # find the length of the variable
# Out:
# a length is 7

# %%
print('a length is', len(a))
# Out:
# a length is 7

# %% [markdown]
# ## String handling

# %%
# Replace the pattern
a.replace('g','G')
# Out:
# 'Hi Guvi'

# %%
# Convert the string into upper case
a.upper()
# Out:
# 'HI GUVI'

# %%
# Convert the string into lower case
a.lower()
# Out:
# 'hi guvi'

# %%
# Convert the string first letter as capital
a.title()
# Out:
# 'Hi Guvi'

# %% [markdown]
# ## Data Slicing

# %%
a = "Hello Guvi"

# %%
# get only the first element as the index starts at 0
a[3]
# Out:
# 'l'

# %%
# Display all the letters in the variable
a[:]
# Out:
# 'Hello Guvi'

# %%
a[0:3]
# Out:
# 'Hel'

# %%
a[1:4]
# Out:
# 'ell'

# %%
# Display all the letters in the variable, len(a) - give the total length of the variable
a[:len(a)]
# Out:
# 'Hello Guvi'

# %%
# display first 3 letters alone
a[:3]
# Out:
# 'Hel'

# %%
# display first 3 letters alone by specifing the start and end
# index starts from 0 and end position is always n-1
a[0:3]
# Out:
# 'Hel'

# %%
# display from 3rd letter till last
a[2:]
# Out:
# 'llo Guvi'

# %%
# display from 3rd letter till 10th letter
a[2:11]
# Out:
# 'llo Guvi'

# %%
# display from 2nd letter till last but before
a[1:-1]
# Out:
# 'ello Guv'

# %%
#reverse the string
a[::-1]
# Out:
# 'ivuG olleH'

# %%
a[::2]
# Out:
# 'HloGv'

# %%
#reverse the string and ignore last 3 letters
a[::-1][:-2]
# Out:
# 'ivuG oll'

# %% [markdown]
# ## Advance or Complex Data Types
# *	Tuple
# *	List
# *	Set
# *	Dictonary

# %% [markdown]
# ## Python Tuple

# %%
image_10 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_02/3.10.png")
display.display(image_10)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1340x551>

# %%
# create a simple tuple only with number

#t =1,2,3  # tuple can be defined this way as well

t = (1,2,3)
t
# Out:
# (1, 2, 3)

# %%
# create a simple tuple only with string

t = ('Hi','guvi')
t
# Out:
# ('Hi', 'guvi')

# %%
# create a simple tuple  with mixed variable

t = (1,"Guvi",2.23,True)
t
# Out:
# (1, 'Guvi', 2.23, True)

# %% [markdown]
# ### 1. Tuple Operations
# A. Repetition (*)
#
# B. Concatenation (+)
#
# C. Membership
#
# D. Length
#
# E. Iteration

# %% [markdown]
# ### 1.A. Repetition:

# %%
Tuple = (1,2,3,4)
Rept = Tuple *2
Rept
# Out:
# (1, 2, 3, 4, 1, 2, 3, 4)

# %% [markdown]
# ### 1.B. Concatenation (+):

# %%
Tuple1 = (1,2,3,4)
Tuple2 = (5,6,7,8)
Concatenation = Tuple1 + Tuple2
Concatenation
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8)
