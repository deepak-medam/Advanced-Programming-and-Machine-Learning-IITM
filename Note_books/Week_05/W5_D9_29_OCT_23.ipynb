# %%
import IPython.display as display
from PIL import Image

# %%
image_01 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_05/9.1.png")
display.display(image_01)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=851x639>

# %% [markdown]
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.

# %% [markdown]
# ## I. Import Pandas library

# %%
import pandas  as pd

# pd is the alias created for the library and it can be anything

# %% [markdown]
# ## II. Introduction to Pandas Structures

# %% [markdown]
# ### Data analysis
# It can be done using 2 different types\
#
#
# *   Data Frame
# *   Series

# %%
image_02 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_05/9.2.png")
display.display(image_02)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=856x636>

# %% [markdown]
# ## III. Series vs Dataframe creation

# %%
image_03 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_05/9.3.png")
display.display(image_03)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=851x631>

# %% [markdown]
# ## IV. Introduction to Pandas Series

# %% [markdown]
# ### Series
#
# Series is a 1 dimension array used in pandas which can store anytype of data types

# %%
image_04 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_05/9.4.png")
display.display(image_04)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=848x632>

# %% [markdown]
# ### Series Ex: 1. Create an empty series

# %%
s =  pd.Series()     # Series - 1 column
print(s)
# Out:
# Series([], dtype: float64)
# <ipython-input-46-2b276b003517>:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s =  pd.Series()     # Series - 1 column

# %% [markdown]
# ### Series Ex: 2. Lets create our first series with data

# %%
# Create a list and convert it into series

data= [ 1,2,3,4,5]
print("data :", data)
print("data type :", type(data))
print()

ser = pd.Series(data)
print("Series :", ser)

print("data type Series:", type(ser))
# Out:
# data : [1, 2, 3, 4, 5]
# data type : <class 'list'>
#
# Series : 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# data type Series: <class 'pandas.core.series.Series'>

# %%
ser
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# ### Series Ex: 3. Check the dimensions

# %%
ser.shape
# Out:
# (5,)

# %% [markdown]
# ### Series Ex: 4. Check the number of elements

# %%
ser.size
# Out:
# 5

# %% [markdown]
# ### Series Ex: 5. Specifying custom index values

# %%
pd.Series([1,2,3,4],index = ['A','B','C','D'])
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %% [markdown]
# ###Series Ex: 5. Create series using random number

# %%
import pandas as pd
import numpy as np
s = pd.Series(np.random.randn(3)) # how many number of random values
print(s)
# Out:
# 0    0.439120
# 1    0.992394
# 2   -0.212377
# dtype: float64

# %% [markdown]
# ### Series Ex: 6. Create random values with custom index

# %%
s = pd.Series(np.random.randn(5), index=['A', 'B', 'C', 'D', 'E'])   #index - 0 to n defalut but index values can be customized
s
# Out:
# A    0.804683
# B    0.631507
# C    1.408743
# D   -1.480790
# E   -0.890775
# dtype: float64

# %% [markdown]
# ### Series Ex: 7. Figuring out the index numbers that are there in the series

# %%
s.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %% [markdown]
# ### Series Ex: 8. Numpy representation of the DataFrame

# %%
s.values
# Out:
# array([ 0.80468257,  0.63150747,  1.4087427 , -1.48079037, -0.89077479])

# %% [markdown]
# ### Series Ex: 9. Create a series using random integer number

# %%
import numpy as np
s = pd.Series(np.random.randint(1,10,5)) # start range, # end range , # how many numbers
print(s)
# Out:
# 0    3
# 1    1
# 2    9
# 3    2
# 4    2
# dtype: int64

# %% [markdown]
# ### Series Ex: 10. Create a series using random integer number with custom index

# %%
s = pd.Series(np.random.randint(1,10,5), index=['A', 'B', 'C', 'D', 'E']) # start range, # end range , # how many numbers
print(s)
# Out:
# A    7
# B    7
# C    5
# D    3
# E    2
# dtype: int64

# %%
# list,tuple, range, random function

# %% [markdown]
# ### Series Ex: 11. Create a dictonary and convert it into series

# %%
data= {1:'TamilNadu',2:'Mumbai',3:'Karnataka'}
ser = pd.Series(data)
print("Series : \n", ser)
# Out:
# Series :
#  1    TamilNadu
# 2       Mumbai
# 3    Karnataka
# dtype: object

# %%
ser
# Out:
# 1    TamilNadu
# 2       Mumbai
# 3    Karnataka
# dtype: object

# %% [markdown]
# ### Series Ex:12. Retrive element using index number.

# %%
ser[1]     # index values and index names

# if key value is string => indexing can be done by index value and index name
# if key value is int => indexing can be done only through index values (index name=index value)
# Out:
# 'TamilNadu'

# %%
ser[[1,2]]
# Out:
# 1    TamilNadu
# 2       Mumbai
# dtype: object

# %%
ser[1:8]  #[start:final:step]   # range function- index value not the index name
# Out:
# 2       Mumbai
# 3    Karnataka
# dtype: object

# %% [markdown]
# ### Series Ex:13. Data modification.

# %%
# Replacing
ser[3] = "Andhra"
print(ser)
# Out:
# 1    TamilNadu
# 2       Mumbai
# 3       Andhra
# dtype: object

# %%
# Adding new row
ser[4]='Delhi'
print(ser)
# Out:
# 1    TamilNadu
# 2       Mumbai
# 3       Andhra
# 4        Delhi
# dtype: object

# %% [markdown]
# ### Series Ex: 14. Create a dictonary and convert it into series (keys with string values)

# %%
data= {'state1':'TamilNadu','state2':'Maharastra','state3':'Karnataka'}
ser = pd.Series(data)
print("Series : \n", ser)
# Out:
# Series :
#  state1     TamilNadu
# state2    Maharastra
# state3     Karnataka
# dtype: object

# %%
ser[0]      #Index value
# Out:
# 'TamilNadu'

# %%
ser['state2']  #Index name
# Out:
# 'Maharastra'

# %%
ser[[1,2]]    #Index value range
# Out:
# state2    Maharastra
# state3     Karnataka
# dtype: object

# %%
ser[['state1','state2']]  #Index name range
# Out:
# state1     TamilNadu
# state2    Maharastra
# dtype: object

# %%
ser[0:2]
# Out:
# state1     TamilNadu
# state2    Maharastra
# dtype: object

# %%
ser
# Out:
# state1     TamilNadu
# state2    Maharastra
# state3     Karnataka
# dtype: object

# %%
ser['state1':'state3']
# Out:
# state1     TamilNadu
# state2    Maharastra
# state3     Karnataka
# dtype: object

# %% [markdown]
# ## Series Ex: 15. Create a nd array and convert it into series
#
# ### N D array

# %%
data = [[1,2,3],[4,5,6]]
data
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
ser = pd.Series(data)
ser
# Out:
# 0    [1, 2, 3]
# 1    [4, 5, 6]
# dtype: object

# %%
ser[0][1]
# Out:
# 2

# %%
ser[1][0]
# Out:
# 4

# %% [markdown]
# ##V. Introduction to Dataframe

# %%
image_05 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_05/9.5.png")
display.display(image_05)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=865x644>

# %%
image_06 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_05/9.6.png")
display.display(image_06)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=852x529>

# %%
image_07 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_05/9.7.png")
display.display(image_07)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=850x571>

# %% [markdown]
# ### DF Ex:1 Create an empty dataframe

# %%
s = pd.DataFrame()
print(s)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### DF Ex:2 Create an empty dataframe with column name alone

# %%
s = pd.DataFrame(columns=['A','B','C','D','E'])
s
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E]
# Index: []

# %% [markdown]
# ### DF Ex:3 Create a dataframe with 5 header but no values

# %%
s = pd.DataFrame(columns=['A','B','C','D','E'], index=[1,2,3,4,5])
s
# Out:
#      A    B    C    D    E
# 1  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN
# 5  NaN  NaN  NaN  NaN  NaN

# %% [markdown]
# ### DF Ex:4 Create a dataframe with 5 rows and 5 columns (dummy header)

# %%
df = pd.DataFrame(np.random.randint(0, 10, size=(5, 5)))
df
# Out:
#    0  1  2  3  4
# 0  7  5  0  1  8
# 1  6  4  2  2  0
# 2  4  0  0  9  8
# 3  1  3  6  5  4
# 4  3  5  7  0  6

# %% [markdown]
# ### DF Ex:5 Create a dataframe with 5 rows and 5 columns (named header)

# %%
np.random.randint(0, 10, size=(5, 5)) #create 5,5 array
# Out:
# array([[4, 5, 1, 8, 8],
#        [8, 2, 4, 0, 6],
#        [0, 1, 7, 3, 1],
#        [3, 3, 7, 4, 1],
#        [5, 5, 5, 7, 8]])

# %%
df = pd.DataFrame(np.random.randint(0, 10, size=(5, 5)),columns=['A','B','C','D','E'])
df
# Out:
#    A  B  C  D  E
# 0  1  5  1  3  7
# 1  9  2  2  9  8
# 2  4  1  3  4  0
# 3  7  1  6  1  8
# 4  8  7  2  0  9

# %% [markdown]
# ### DF Ex:6 Create a dataframe with 5 rows and 5 columns (apply split in column names)

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame(np.random.randint(0, 100, size=(5, 5)), columns='a b c d e'.split())
df
# Out:
#     a   b   c   d   e
# 0  49  97  54  26  13
# 1  59  55  44  25  15
# 2  99  18  76  55   7
# 3  67  26  84  41   4
# 4  88  44  97  10  50

# %% [markdown]
# ### DF Ex:7 Create a dataframe with 5 rows and 5 columns (apply split in column names)

# %%
df = pd.DataFrame({'A' : [1,2,3,4,5], 'B' : [5,6,7,8,9], 'C' : [1,2,3,4,5]})
df
# Out:
#    A  B  C
# 0  1  5  1
# 1  2  6  2
# 2  3  7  3
# 3  4  8  4
# 4  5  9  5

# %%
#set date as index
array =  {'A' : [1, 2, 3, 4],'B' : [4, 3, 2, 1]}
index = pd.DatetimeIndex(['01-01-2020', '2020-12-02','2020-12-03', '2020-12-04'])
pd.DataFrame(array, index=index)
# Out:
#             A  B
# 2020-01-01  1  4
# 2020-12-02  2  3
# 2020-12-03  3  2
# 2020-12-04  4  1

# %% [markdown]
# ### DF Ex:8 Create 3 different list, combine it as dict and convert it into a dataframe

# %%
names = ['Ram', 'John', 'Abdul','Siva', 'Adam', 'Rahman']
maths =  [45, 40, 60, 80, 90, 75]
english =[60,75,90,65,80,60]
scores = { 'Student_Name':names, 'Maths':maths, 'English':english } # converted dict
scores_df = pd.DataFrame(scores,index= names)  #DataFrame
print(names)
print(scores_df)
# Out:
# ['Ram', 'John', 'Abdul', 'Siva', 'Adam', 'Rahman']
#        Student_Name  Maths  English
# Ram             Ram     45       60
# John           John     40       75
# Abdul         Abdul     60       90
# Siva           Siva     80       65
# Adam           Adam     90       80
# Rahman       Rahman     75       60

# %%
scores_df
# Out:
#        Student_Name  Maths  English
# Ram             Ram     45       60
# John           John     40       75
# Abdul         Abdul     60       90
# Siva           Siva     80       65
# Adam           Adam     90       80
# Rahman       Rahman     75       60

# %%
scores_df.index
# Out:
# Index(['Ram', 'John', 'Abdul', 'Siva', 'Adam', 'Rahman'], dtype='object')

# %% [markdown]
# ### DF Ex:9 Return the first n rows

# %%
# get first  2 records alone

scores_df.head()  # default=5
# Out:
#       Student_Name  Maths  English
# Ram            Ram     45       60
# John          John     40       75
# Abdul        Abdul     60       90
# Siva          Siva     80       65
# Adam          Adam     90       80

# %% [markdown]
# ### DF Ex:10 Return the last n rows

# %%
# get last  2 records alone

scores_df.tail(3)
# Out:
#        Student_Name  Maths  English
# Siva           Siva     80       65
# Adam           Adam     90       80
# Rahman       Rahman     75       60

# %% [markdown]
# ### DF Ex:11 Renaming Columns

# %%
print(scores_df.index)
# Out:
# Index(['Ram', 'John', 'Abdul', 'Siva', 'Adam', 'Rahman'], dtype='object')

# %%
scores_df.columns
# Out:
# Index(['Student_Name', 'Maths', 'English'], dtype='object')

# %%
scores_df.head(1)
# Out:
#     Student_Name  Maths  English
# Ram          Ram     45       60

# %%
scores_df.columns = ['Names','Physics','Chemistry']    # Renaming columns from english , maths to physics and chemistry
scores_df.head(2)
# Out:
#      Names  Physics  Chemistry
# Ram    Ram       45         60
# John  John       40         75

# %%
# replace Chemistry with Maths
scores_df.rename({'Chemistry':'Maths'},axis=1,inplace=True)   # Renaming columns   # axis=1 => columns

# %%
scores_df
# Out:
#          Names  Physics  Maths
# Ram        Ram       45     60
# John      John       40     75
# Abdul    Abdul       60     90
# Siva      Siva       80     65
# Adam      Adam       90     80
# Rahman  Rahman       75     60

# %%
scores_df.rename({'Siva':'Krishna'},axis=0,inplace=True)  # Renaming rows    #axis=0 => rows
scores_df
# Out:
#           Names  Physics  Maths
# Ram         Ram       45     60
# John       John       40     75
# Abdul     Abdul       60     90
# Krishna    Siva       80     65
# Adam       Adam       90     80
# Rahman   Rahman       75     60

# %% [markdown]
# ### DF Ex:12 Slicing the dataframe (Single Column)

# %%
scores_df['Maths']  # column slicing
# Out:
# Ram        60
# John       75
# Abdul      90
# Krishna    65
# Adam       80
# Rahman     60
# Name: Maths, dtype: int64

# %%
scores_df[['Maths']]
# Out:
#          Maths
# Ram         60
# John        75
# Abdul       90
# Krishna     65
# Adam        80
# Rahman      60

# %% [markdown]
# ### DF Ex:13 Slicing the dataframe (Mutiple Column)

# %%
scores_df[['Names','Maths']]
# Out:
#           Names  Maths
# Ram         Ram     60
# John       John     75
# Abdul     Abdul     90
# Krishna    Siva     65
# Adam       Adam     80
# Rahman   Rahman     60

# %% [markdown]
# ### DF Ex:14 Slicing the dataframe (row slicing)

# %%
scores_df[0:3]
# Out:
#        Names  Physics  Maths
# Ram      Ram       45     60
# John    John       40     75
# Abdul  Abdul       60     90

# %%
scores_df[2:5]
# Out:
#          Names  Physics  Maths
# Abdul    Abdul       60     90
# Krishna   Siva       80     65
# Adam      Adam       90     80

# %%
scores_df[:3]       # first row till 3rd
# Out:
#        Names  Physics  Maths
# Ram      Ram       45     60
# John    John       40     75
# Abdul  Abdul       60     90

# %%
scores_df[2:] # 2nd row till last
# Out:
#           Names  Physics  Maths
# Abdul     Abdul       60     90
# Krishna    Siva       80     65
# Adam       Adam       90     80
# Rahman   Rahman       75     60

# %% [markdown]
# ### DF Ex:15 Slicing the dataframe (fetch only the first and second record only for column physics)

# %%
scores_df[0:2]['Physics']
# Out:
# Ram     45
# John    40
# Name: Physics, dtype: int64

# %% [markdown]
# ### DF Ex:16 Slicing the dataframe (fetch only the second and third record only for columns physics and maths)

# %%
scores_df[2:4][['Physics','Maths']]
# Out:
#          Physics  Maths
# Abdul         60     90
# Krishna       80     65

# %%
scores_df[['Physics','Maths']][2:4]
# Out:
#          Physics  Maths
# Abdul         60     90
# Krishna       80     65

# %%
scores_df[['Physics','Maths']]['Abdul':'Krishna']
# Out:
#          Physics  Maths
# Abdul         60     90
# Krishna       80     65

# %% [markdown]
# ## VI. Creating dataframe using Dictionary (.from_dict)

# %% [markdown]
# The default manner to create a DataFrame from python is to use a list of dictionaries. In this case each dictionary key is used for the column headings. A default index will be created automatically:

# %%
gg= ({"Location":"Bangalore","Jan":150,"Feb":80},
    {"Location":"Chennai","Jan":200,"Feb":70})
Df = pd.DataFrame(gg)
Df
# Out:
#     Location  Jan  Feb
# 0  Bangalore  150   80
# 1    Chennai  200   70

# %%
Guvi = ({"Location":["Bangalore","Chennai"],
      "Jan":[150,80],
      "Feb":[200,70]})

df = pd.DataFrame.from_dict(Guvi)
df
# Out:
#     Location  Jan  Feb
# 0  Bangalore  150  200
# 1    Chennai   80   70

# %% [markdown]
# ## VII. Creating dataframe using List

# %% [markdown]
# The other option for creating your DataFrames from python is to include the data in a list structure.
#
# The first approach is to use a row oriented approach using pandas from_records . This approach is similar to the dictionary approach but you need to explicitly call out the column labels.

# %%
Guvi = [("Bangalore",150,80),
     ("Chennai",200,70)]
Labels = ["Location","Jan","Feb"]
df = pd.DataFrame.from_records(Guvi,columns=Labels)
df
# Out:
#     Location  Jan  Feb
# 0  Bangalore  150   80
# 1    Chennai  200   70

# %%
Guvi = [("Location", ["Bangalore","Chennai"]),("Jan",[150,200]),("Feb",[80,70])]

# Extract the column names and data from the list of tuples
columns = [item[0] for item in Guvi]
data = [item[1] for item in Guvi]

# Create the DataFrame
df1 = pd.DataFrame(dict(zip(columns, data)))
print(df1)
# Out:
#     Location  Jan  Feb
# 0  Bangalore  150   80
# 1    Chennai  200   70
