# %%
import IPython.display as display
from PIL import Image

# %% [markdown]
# ## Python Jupyter Environment

# %% [markdown]
# ### Drop down

# %%
# code - python code option
# Markdown - it also works like heading, it is also used to add images
# Raw NBConvert - copy and paste the text from different text or the math formula's
# Heading - as # increased the header size decreases

# %% [markdown]
# ### Icons

# %%
# Save
# Add
# cut
# up arrow
# down arrow
# run
# stop
# restart kernel

# %% [markdown]
# ### File Creation

# %%
# How to create a new file
# open an existing file
# delete a file
# rename a file

# %% [markdown]
# ### Why Jupyter notebook

# %%
# Can add header  and prepare detailed notes
# can add images and relavant formulas
# code snippet
# output result can also be saved
# Mainly used for learning , assignment, mini project and project submission

# %% [markdown]
# ## Introductions to Python

# %% [markdown]
# ### Single line comment

# %%
# This is a "block comment" in Python is Single line comments
#'Today is first python session'

# %% [markdown]
# ### Multi line comment control + l

# %%
 """
This is a "block comment" in Python, made
out of a mult-line string constant.
This actually works quite well!
"""
# Out:
# '\nThis is a "block comment" in Python, made\nout of a mult-line string constant.\nThis actually works quite well!\n'

# %%
"""" this is first python session.
we will learn basic concepts"""
# Out:
# '" this is first python session.\nwe will learn basic concepts'

# %%
'hello guvi'
# Out:
# 'hello guvi'

# %%
4+7
# Out:
# 11

# %% [markdown]
# ### Printing Multiple lines

# %%
"""This is a "block comment" in Python, made
out of a mult-line string constant.
This actually works quite well!
"""
# Out:
# 'This is a "block comment" in Python, made\nout of a mult-line string constant.\nThis actually works quite well!\n'

# %% [markdown]
# ### printing the string in 2 different ways

# %%
print("welcome to Python coding")

print('welcome to Python coding')
# Out:
# welcome to Python coding
# welcome to Python coding

# %%
#Printing multiple lines with newline
print('welcome to Python coding')
print('\n')
print('welcome to Python coding')
# Out:
# welcome to Python coding
#
#
# welcome to Python coding

# %%
pnt='welcome to guvi'
pnt
# Out:
# 'welcome to guvi'

# %%
#Printing multiple lines with newline
print('welcome to Python coding\n')

print('welcome to Python coding')
# Out:
# welcome to Python coding
#
# welcome to Python coding

# %%
#Printing multiple lines with newline
print('welcome to Python coding','\n')

print('welcome to Python coding')
# Out:
# welcome to Python coding
#
# welcome to Python coding

# %% [markdown]
# ## Variables

# %% [markdown]
# ### Pseudocode : Create an employee form and list the important fields

# %%
# Employee name : "Guvi"
# Employee id : 100
# Dept : "CSE"
# Email : helloguvi@guvi.in
# Contact :044 23412345
# Age : 26
# height : 5.10
# Weight 72
# Salary : 50000
# City : "Chennai"

# %% [markdown]
# ### Inference with the above sample data collected

# %%
# Input received falls under 2 category
    # * String or text
    # * Number

 # String can include both alphabet, numbers or special characters
 #Number can be classified into Integer (without decimal  eg. 1 or 5  or 10) , Float ( decimal - eg 1.0 , 4.32. 5.2)

# Pseudocode

# * Start the program
# * create fields or columns or parameters or variable
# * allocated or assign values to them
# * display the output
# * end of the code

# %% [markdown]
# ### Variable

# %%
image_01 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_01/2.1.png")
display.display(image_01)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1171x535>

# %%
# Assign an integer to a variable a
a = 3
a
type(a)
# Out:
# int

# %%
# Assign a float to a variable f

f = 1.2
print(f)
type(f)
# Out:
# 1.2
# float

# %%
# Assign a string to a variable str
s = "456is my lucky num"
type(s)
# Out:
# str

# %%
# Assign a string to a variable str
# True or False - first character should be caps
b = True
type(b)
# Out:
# bool

# %%
b='suresh'
print(b)
# Out:
# suresh

# %%
# when we use multiple print statement, it will print all variable inside print
a=2
b=3
c=4
a
print(b)
print(c)
# Out:
# 3
# 4

# %%
# in this case , print and last variable(in case of multiple variable after print statement) will be executed.
print(a)
b
c
# Out:
# 2
# 4

# %%
# Print all the variables
print(a)
print(f)
print(float)
# Out:
# 2
# 1.2
# <class 'float'>

# %%
#Print with text

print("a :",a)
print("f :",f)
print("str :",str)
# Out:
# a : 2
# f : 1.2
# str : <class 'str'>

# %% [markdown]
# ### reassign the variable

# %%
a=4
b=3

# reassign the values
b = a   # a holds 4 so b=4
a = b   # b holds 4 so a =4
print(a)
print(b)
# Out:
# 4
# 4

# %%
a=5
b='Hello Guvi'
c=125
f=22.6

# Print all the variable with some text attached to it
print(" Value of a is :", a)
print(" Value of b is :",b)
print(" Value of c is :",c)
print(" Value of f is :",f)
# Out:
#  Value of a is : 5
#  Value of b is : Hello Guvi
#  Value of c is : 125
#  Value of f is : 22.6

# %% [markdown]
# ### Multiple variable and Multiple assignment

# %%
i,j,k =2,4,6
print("i:",i)
print("j:",j)
print("k:",k)
# Out:
# i: 2
# j: 4
# k: 6

# %% [markdown]
# ### Multiple variable and same assignment of values

# %%
x = y = z =10
print("x:",x)
print("y:",y)
print("z:",z)
# Out:
# x: 10
# y: 10
# z: 10

# %% [markdown]
# ## Python Data Types

# %%
image_02 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_01/2.2.png")
display.display(image_02)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1340x551>

# %%
image_03 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_01/2.3.png")
display.display(image_03)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1340x551>

# %% [markdown]
# ## Assign a variable and find its Data types

# %% [markdown]
# ### 1. int

# %%
a = 4
print(a)
print(type(a))
# Out:
# 4
# <class 'int'>

# %% [markdown]
# ### 2. float

# %%
a = 4.5
print(a)
print(type(a))
# Out:
# 4.5
# <class 'float'>

# %% [markdown]
# ### 3. Complex Numbers

# %%
a = 4+2j
print(a)
print(type(a))
# Out:
# (4+2j)
# <class 'complex'>

# %% [markdown]
# ### 4. String

# %%
s = '4'
print(s)
print(type(s))
# Out:
# 4
# <class 'str'>

# %%
s = 'hi'
print(s[1]) # print second element
print(len(s) )
print(s + ' there')
print(type(s))
# Out:
# i
# 2
# hi there
# <class 'str'>

# %%
s = 'hi'
print(s[0:5]) # range of index is given so it will print all element
print(len(s) )
print(s + ' there')
print(type(s))
# Out:
# hi
# 2
# hi there
# <class 'str'>

# %%
s = 'hi'
print(s[8])  # here we are triying to fetch that idex value 8 which doesn't exist,error- index out of range.
print(len(s) )
print(s + ' there')
print(type(s))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-66-48f4676b0d3a> in <cell line: 2>()
#       1 s = 'hi'
# ----> 2 print(s[8])  # here we are triying to fetch that idex value 8 which doesn't exist,error- index out of range.
#       3 print(len(s) )
#       4 print(s + ' there')
#       5 print(type(s))
#
# IndexError: string index out of range

# %% [markdown]
# ### 4.Boolean

# %%
x = True
print(x)
print(type(x))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# ## Data Type Conversion

# %%
image_04 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_01/2.4.png")
display.display(image_04)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1340x551>

# %% [markdown]
# ### 1. Implicit Conversion:

# %%
a = 4
b = 0.5
print(a)
print(type(a))
# Out:
# 4
# <class 'int'>

# %%
print(b)
print(type(b))
# Out:
# 0.5
# <class 'float'>

# %% [markdown]
# #### •	Int + Float = Float

# %%
c = a + b
print(c)
print(type(c))
# Out:
# 4.5
# <class 'float'>

# %% [markdown]
# ### 2. Explicit Conversion:

# %%
image_05 = Image.open("/content/drive/MyDrive/2023-24/courses/Advanced-Programming-and-Machine-Learning-IITM/Images/Week_01/2.5.png")
display.display(image_05)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1340x551>

# %% [markdown]
# ### 1. int()

# %%
int(131.5)
# Out:
# 131

# %% [markdown]
# ### 2. float()

# %%
float(131)
# Out:
# 131.0

# %% [markdown]
# ### 3.1.complex(X):

# %%
complex(10,2)
# Out:
# (10+2j)

# %% [markdown]
# ### 3.2 complex(X,Y):

# %%
complex(10,20)
# Out:
# (10+20j)

# %% [markdown]
# ###4. Str()

# %%
a=10
print(str(a))
# Out:
# 10

# %%
x=45
y=str(x)
print(y)
print(type(y))
# Out:
# 45
# <class 'str'>

# %% [markdown]
# ###5. bool()

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(10)
# Out:
# True

# %%
bool(-10)
# Out:
# True
